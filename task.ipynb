# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://www.indiatvnews.com/business/news-india-gdp-quickest-to-fall-fastest-to-recover-673985"
try:
    page = urlopen(url)
except:
    print("Error opening the URL")

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
content = soup.find('div', {"class":"content"})

# %%
article = ''
for i in content.findAll('p'):
    article = article + ' ' +  i.text

# %%
with open('scraped_text.txt', 'w') as file:
    file.write(article)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
content = open("scraped_text.txt", "r").read()
print(content)
# Out:
#  (Representational image) The covid-19 induced turmoil showed weakness as well as resilience of India's economy in 2020, as the country's GDP recorded abysmal fall and breathtaking recovery. The economy, which faced a severe slowdown prior to the pandemic, was decimated due to the lockdown imposed to curb the pandemic's spread. Accordingly, the country's GDP contracted by more than 23 per cent in Q1FY21. Nonetheless, slow tapering of mobility and lockdown restrictions along with pent up demand narrowed this contraction to under 10 per cent in Q2FY21. Consequently, the country entered into a technical recession. Nevertheless, festive season, pent up demand and rise in discretionary spending coupled with massive liquidity and government stimulus triggered one the fastest recovery pattern seen anywhere in the world. ALSO READ | 'People won't be misled': PM Modi rips into opposition for spreading lies on new farm laws Some economy watchers described the phenomenon as a 'V' shaped recovery, whereas, others pointed it out as 'U' formation for the restoration of economic normalcy. All in all, sector after sector reported sequential growth with many crossing the year on year sales and production levels. Besides, various factors such as a low base, restocking and higher discretionary spends were cited for the heightened economic activity which was led by agriculture, electricity and the manufacturing sectors. Even though cheaper interest rates helped in spurring consumption, other vitals such as lower oil prices, lesser imports and an accelerated pick up of agricultural and pharma exports added positivity to the economic scene. After a healthy monsoon, the country's festive season coupled with 'unlock' measures opened the floodgates for retail, wholesale and restocking, thereby, moving the wheels of economic revival. Furthermore, stock markets boomed, as macro-economic data and better-than-expected quarterly results attracted FIIs with prospects of a return, something that has been missing in other asset classes throughout the year. "A tentative recovery in volumes is underway, which is being counteracted by rising raw material prices and to a smaller extent employee costs. We expect the recovery to continue, albeit with a mild contraction in Q3 followed by a muted growth in Q4," said Aditi Nayar, Principal Economist, ICRA.    googletag.cmd.push(function () { googletag.display('div-gpt-ad-1516086534511-1'); });   On a sector specific basis, while agriculture and allied industries pushed the economy forward, manufacturing too came out of its doldrums even though it has dipped slightly ever since. However, the service sector's contribution was lacking in giving a real push to the GDP. Now with hopes of a mass immunisation programme armed with a high efficacy backed vaccine, front and back end services are expected to bounce back. "The next leg of sequential recovery may emerge from services which has been a laggard so far, while government spending may also improve at the margin," Emkay Global's Lead Economist Madhavi Arora said. "We see FY21 growth at (-)7.1 per cent with a mild downward bias. We reckon while 2HFY21 will see further pick up, sustaining sequential growth momentum beyond that will require easing domestic structural overhang, continued innovative policy support and better global backdrop," she added. Apart from the government spending or the private final consumption, it was savings backed discretionary spends of common households that came in as a saviour for the economy. "We believe that the accumulated savings of particularly the Indian salaried class over the last 7-8 months due to limited expenses on travel and entertainment will get partly diverted to the purchase of vehicles and consumer durables," Acuite Ratings & Research Chief Analytical Officer Suman Chowdhury said. "This is already reflected in the uptick in the demand of these products. The pent up demand and the availability of higher savings, therefore is ex ...

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(content)))

# %%
print(ne_tree)
# Out:
# (S
#   (/(
#   Representational/NNP
#   image/NN
#   )/)
#   The/DT
#   covid-19/NN
#   induced/JJ
#   turmoil/NN
#   showed/VBD
#   weakness/NN
#   as/RB
#   well/RB
#   as/IN
#   resilience/NN
#   of/IN
#   (GPE India/NNP)
#   's/POS
#   economy/NN
#   in/IN
#   2020/CD
#   ,/,
#   as/IN
#   the/DT
#   country/NN
#   's/POS
#   (ORGANIZATION GDP/NNP)
#   recorded/VBD
#   abysmal/JJ
#   fall/NN
#   and/CC
#   breathtaking/JJ
#   recovery/NN
#   ./.
#   The/DT
#   economy/NN
#   ,/,
#   which/WDT
#   faced/VBD
#   a/DT
#   severe/JJ
#   slowdown/NN
#   prior/RB
#   to/TO
#   the/DT
#   pandemic/NN
#   ,/,
#   was/VBD
#   decimated/VBN
#   due/JJ
#   to/TO
#   the/DT
#   lockdown/NN
#   imposed/VBN
#   to/TO
#   curb/VB
#   the/DT
#   pandemic/NN
#   's/POS
#   spread/NN
#   ./.
#   Accordingly/RB
#   ,/,
#   the/DT
#   country/NN
#   's/POS
#   (ORGANIZATION GDP/NNP)
#   contracted/VBN
#   by/IN
#   more/JJR
#   than/IN
#   23/CD
#   per/IN
#   cent/NN
#   in/IN
#   (GPE Q1FY21/NNP)
#   ./.
#   Nonetheless/NNP
#   ,/,
#   slow/JJ
#   tapering/NN
#   of/IN
#   mobility/NN
#   and/CC
#   lockdown/JJ
#   restrictions/NNS
#   along/IN
#   with/IN
#   pent/NN
#   up/RB
#   demand/NN
#   narrowed/VBD
#   this/DT
#   contraction/NN
#   to/TO
#   under/IN
#   10/CD
#   per/IN
#   cent/NN
#   in/IN
#   (GPE Q2FY21/NNP)
#   ./.
#   Consequently/RB
#   ,/,
#   the/DT
#   country/NN
#   entered/VBD
#   into/IN
#   a/DT
#   technical/JJ
#   recession/NN
#   ./.
#   Nevertheless/NNP
#   ,/,
#   festive/JJ
#   season/NN
#   ,/,
#   pent/NN
#   up/RB
#   demand/NN
#   and/CC
#   rise/NN
#   in/IN
#   discretionary/JJ
#   spending/NN
#   coupled/VBN
#   with/IN
#   massive/JJ
#   liquidity/NN
#   and/CC
#   government/NN
#   stimulus/NN
#   triggered/VBD
#   one/CD
#   the/DT
#   fastest/JJS
#   recovery/NN
#   pattern/NN
#   seen/VBN
#   anywhere/RB
#   in/IN
#   the/DT
#   world/NN
#   ./.
#   (ORGANIZATION ALSO/NNP)
#   READ/NNP
#   |/NNP
#   'People/NNP
#   wo/MD
#   n't/RB
#   be/VB
#   misled/VBN
#   '/POS
#   :/:
#   PM/NNP
#   Modi/NNP
#   rips/VBZ
#   into/IN
#   opposition/NN
#   for/IN
#   spreading/VBG
#   lies/NNS
#   on/IN
#   new/JJ
#   farm/NN
#   laws/NNS
#   Some/DT
#   economy/NN
#   watchers/NNS
#   described/VBD
#   the/DT
#   phenomenon/NN
#   as/IN
#   a/DT
#   '/''
#   V/NNP
#   '/POS
#   shaped/JJ
#   recovery/NN
#   ,/,
#   whereas/NNS
#   ,/,
#   others/NNS
#   pointed/VBD
#   it/PRP
#   out/RP
#   as/IN
#   '/''
#   U/NNP
#   '/POS
#   formation/NN
#   for/IN
#   the/DT
#   restoration/NN
#   of/IN
#   economic/JJ
#   normalcy/NN
#   ./.
#   All/DT
#   in/IN
#   all/DT
#   ,/,
#   sector/NN
#   after/IN
#   sector/NN
#   reported/VBD
#   sequential/JJ
#   growth/NN
#   with/IN
#   many/JJ
#   crossing/VBG
#   the/DT
#   year/NN
#   on/IN
#   year/NN
#   sales/NNS
#   and/CC
#   production/NN
#   levels/NNS
#   ./.
#   Besides/IN
#   ,/,
#   various/JJ
#   factors/NNS
#   such/JJ
#   as/IN
#   a/DT
#   low/JJ
#   base/NN
#   ,/,
#   restocking/VBG
#   and/CC
#   higher/JJR
#   discretionary/JJ
#   spends/NNS
#   were/VBD
#   cited/VBN
#   for/IN
#   the/DT
#   heightened/JJ
#   economic/JJ
#   activity/NN
#   which/WDT
#   was/VBD
#   led/VBN
#   by/IN
#   agriculture/NN
#   ,/,
#   electricity/NN
#   and/CC
#   the/DT
#   manufacturing/NN
#   sectors/NNS
#   ./.
#   Even/RB
#   though/IN
#   cheaper/JJR
#   interest/NN
#   rates/NNS
#   helped/VBD
#   in/IN
#   spurring/VBG
#   consumption/NN
#   ,/,
#   other/JJ
#   vitals/NNS
#   such/JJ
#   as/IN
#   lower/JJR
#   oil/NN
#   prices/NNS
#   ,/,
#   lesser/JJR
#   imports/NNS
#   and/CC
#   an/DT
#   accelerated/VBN
#   pick/NN
#   up/IN
#   of/IN
#   agricultural/JJ
#   and/CC
#   pharma/JJ
#   exports/NNS
#   added/VBD
#   positivity/NN
#   to/TO
#   the/DT
#   economic/JJ
#   scene/NN
#   ./.
#   After/IN
#   a/DT
#   healthy/JJ
#   monsoon/NN
#   ,/,
#   the/DT
#   country/NN
#   's/POS
#   festive/JJ
#   season/NN
#   coupled/VBN
#   with/IN
#   'unlock/NNP
#   '/POS
#   measures/NNS
#   opened/VBD
#   the/DT
#   floodgates/NNS
#   for/IN
#   retail/NN
#   ,/,
#   wholesale/JJ
#   and/CC
#   restocking/NN
#   ,/,
#   thereby/RB
#   ,/,
#   moving/VBG
#   the/DT
#   wheels/NNS
#   of/IN
#   economic/JJ
#   revival/NN
#   ./.
#   Furthermore/NNP
#   ,/,
#   stock/NN
#   markets/NNS
#   boomed/VBD
#   ,/,
#   as/IN
#   macro-economic/JJ
#   data/NNS
#   and/CC
#   better-than-expected/JJ
#   quarterly/JJ
#   results/NNS
#   attracted/VBD
#   (ORGANIZATION FIIs/NNP)
#   with/IN
#   prospects/NNS
#   of/IN
#   a/DT
#   return/NN
#   ,/,
#   something/NN
#   that/WDT
#   has/VBZ
#   been/VBN
#   missing/VBG
#   in/IN
#   other/JJ
#   asset/NN
#   classes/NNS
#   throughout/IN
#   the/DT
#   year/NN
#   ./.
#   ``/``
#   A/DT
#   tentative/JJ
#   recovery/NN
#   in/IN
#   volumes/NNS
#   is/VBZ
#   underway/RB
#   ,/,
#   which/WDT
#   is/VBZ
#   being/VBG
#   counteracted/VBN
#   by/IN
#   rising/VBG
#   raw/JJ
#   material/NN
#   prices/NNS
#   and/CC
#   to/TO
#   a/DT
#   smaller/JJR
#   extent/NN
#   employee/NN
#   costs/NNS
#   ./.
#   We/PRP
#   expect/VBP
#   the/DT
#   recovery/NN
#   to/TO
#   continue/VB
#   ,/,
#   albeit/IN
#   with/IN
#   a/DT
#   mild/JJ
#   contraction/NN
#   in/IN
#   (GPE Q3/NNP)
#   followed/VBN
#   by/IN
#   a/DT
#   muted/JJ
#   growth/NN
#   in/IN
#   (GPE Q4/NNP)
#   ,/,
#   ''/''
#   said/VBD
#   (PERSON Aditi/NNP Nayar/NNP)
#   ,/,
#   (PERSON Principal/NNP Economist/NNP)
#   ,/,
#   (ORGANIZATION ICRA/NNP)
#   ./.
#   googletag.cmd.push/NN
#   (/(
#   function/NN
#   (/(
#   )/)
#   {/(
#   googletag.display/NN
#   (/(
#   'div-gpt-ad-1516086534511-1/JJ
#   '/''
#   )/)
#   ;/:
#   }/)
#   )/)
#   ;/:
#   On/IN
#   a/DT
#   sector/NN
#   specific/JJ
#   basis/NN
#   ,/,
#   while/IN
#   agriculture/NN
#   and/CC
#   allied/JJ
#   industries/NNS
#   pushed/VBD
#   the/DT
#   economy/NN
#   forward/RB
#   ,/,
#   manufacturing/VBG
#   too/RB
#   came/VBD
#   out/IN
#   of/IN
#   its/PRP$
#   doldrums/NNS
#   even/RB
#   though/IN
#   it/PRP
#   has/VBZ
#   dipped/VBN
#   slightly/RB
#   ever/RB
#   since/IN
#   ./.
#   However/RB
#   ,/,
#   the/DT
#   service/NN
#   sector/NN
#   's/POS
#   contribution/NN
#   was/VBD
#   lacking/VBG
#   in/IN
#   giving/VBG
#   a/DT
#   real/JJ
#   push/NN
#   to/TO
#   the/DT
#   (ORGANIZATION GDP/NNP)
#   ./.
#   Now/RB
#   with/IN
#   hopes/NNS
#   of/IN
#   a/DT
#   mass/NN
#   immunisation/NN
#   programme/NN
#   armed/VBN
#   with/IN
#   a/DT
#   high/JJ
#   efficacy/NN
#   backed/VBD
#   vaccine/NN
#   ,/,
#   front/NN
#   and/CC
#   back/RB
#   end/NN
#   services/NNS
#   are/VBP
#   expected/VBN
#   to/TO
#   bounce/VB
#   back/RB
#   ./.
#   ``/``
#   The/DT
#   next/JJ
#   leg/NN
#   of/IN
#   sequential/JJ
#   recovery/NN
#   may/MD
#   emerge/VB
#   from/IN
#   services/NNS
#   which/WDT
#   has/VBZ
#   been/VBN
#   a/DT
#   laggard/NN
#   so/RB
#   far/RB
#   ,/,
#   while/IN
#   government/NN
#   spending/NN
#   may/MD
#   also/RB
#   improve/VB
#   at/IN
#   the/DT
#   margin/NN
#   ,/,
#   ''/''
#   (PERSON Emkay/NNP Global/NNP)
#   's/POS
#   (ORGANIZATION Lead/NNP Economist/NNP Madhavi/NNP Arora/NNP)
#   said/VBD
#   ./.
#   ``/``
#   We/PRP
#   see/VBP
#   (ORGANIZATION FY21/JJ)
#   growth/NN
#   at/IN
#   (/(
#   -/:
#   )/)
#   7.1/CD
#   per/IN
#   cent/NN
#   with/IN
#   a/DT
#   mild/JJ
#   downward/JJ
#   bias/NN
#   ./.
#   We/PRP
#   reckon/VBP
#   while/IN
#   2HFY21/CD
#   will/MD
#   see/VB
#   further/RB
#   pick/VB
#   up/RP
#   ,/,
#   sustaining/VBG
#   sequential/JJ
#   growth/NN
#   momentum/NN
#   beyond/IN
#   that/DT
#   will/MD
#   require/VB
#   easing/VBG
#   domestic/JJ
#   structural/JJ
#   overhang/NN
#   ,/,
#   continued/VBD
#   innovative/JJ
#   policy/NN
#   support/NN
#   and/CC
#   better/JJR
#   global/JJ
#   backdrop/NN
#   ,/,
#   ''/''
#   she/PRP
#   added/VBD
#   ./.
#   Apart/RB
#   from/IN
#   the/DT
#   government/NN
#   spending/NN
#   or/CC
#   the/DT
#   private/JJ
#   final/JJ
#   consumption/NN
#   ,/,
#   it/PRP
#   was/VBD
#   savings/NNS
#   backed/VBD
#   discretionary/JJ
#   spends/NNS
#   of/IN
#   common/JJ
#   households/NNS
#   that/WDT
#   came/VBD
#   in/IN
#   as/IN
#   a/DT
#   saviour/NN
#   for/IN
#   the/DT
#   economy/NN
#   ./.
#   ``/``
#   We/PRP
#   believe/VBP
#   that/IN
#   the/DT
#   accumulated/JJ
#   savings/NNS
#   of/IN
#   particularly/RB
#   the/DT
#   (GPE Indian/JJ)
#   salaried/JJ
#   class/NN
#   over/IN
#   the/DT
#   last/JJ
#   7-8/JJ
#   months/NNS
#   due/JJ
#   to/TO
#   limited/JJ
#   expenses/NNS
#   on/IN
#   travel/NN
#   and/CC
#   entertainment/NN
#   will/MD
#   get/VB
#   partly/RB
#   diverted/VBN
#   to/TO
#   the/DT
#   purchase/NN
#   of/IN
#   vehicles/NNS
#   and/CC
#   consumer/NN
#   durables/NNS
#   ,/,
#   ''/''
#   (PERSON Acuite/NNP Ratings/NNP)
#   &/CC
#   (PERSON Research/NNP Chief/NNP Analytical/NNP)
#   Officer/NNP
#   (PERSON Suman/NNP Chowdhury/NNP)
#   said/VBD
#   ./.
#   ``/``
#   This/DT
#   is/VBZ
#   already/RB
#   reflected/VBN
#   in/IN
#   the/DT
#   uptick/NN
#   in/IN
#   the/DT
#   demand/NN
#   of/IN
#   these/DT
#   products/NNS
#   ./.
#   The/DT
#   pent/NN
#   up/RB
#   demand/NN
#   and/CC
#   the/DT
#   availability/NN
#   of/IN
#   higher/JJR
#   savings/NNS
#   ,/,
#   therefore/RB
#   is/VBZ
#   expected/VBN
#   to/TO
#   drive/VB
#   consumption/NN
#   demand/NN
#   over/IN
#   the/DT
#   next/JJ
#   1-2/JJ
#   quarters/NNS
#   ,/,
#   ''/''
#   (PERSON Chowdhury/NNP)
#   added/VBD
#   ./.
#   Other/JJ
#   than/IN
#   stimulus/NN
#   ,/,
#   the/DT
#   (ORGANIZATION Centre/NNP)
#   's/POS
#   structural/JJ
#   reforms/NNS
#   ,/,
#   focus/NN
#   on/IN
#   the/DT
#   manufacturing/NN
#   sector/NN
#   and/CC
#   inflow/NN
#   of/IN
#   (ORGANIZATION FDI/NNP)
#   into/IN
#   the/DT
#   country/NN
#   are/VBP
#   likely/JJ
#   to/TO
#   hasten/VB
#   the/DT
#   pace/NN
#   of/IN
#   economic/JJ
#   recovery/NN
#   ./.
#   According/VBG
#   to/TO
#   (PERSON Brickwork/NNP Ratings/NNP)
#   '/POS
#   Chief/NNP
#   Economic/NNP
#   (PERSON Adviser/NNP M./NNP Govinda/NNP Rao/NNP)
#   :/:
#   ``/``
#   The/DT
#   economy/NN
#   will/MD
#   continue/VB
#   to/TO
#   recover/VB
#   as/IN
#   restrictions/NNS
#   are/VBP
#   relaxed/JJ
#   and/CC
#   capacity/NN
#   utilisation/NN
#   improves/VBZ
#   ./.
#   It/PRP
#   is/VBZ
#   important/JJ
#   to/TO
#   undertake/VB
#   structural/JJ
#   reforms/NNS
#   to/TO
#   accelerate/VB
#   the/DT
#   pace/NN
#   of/IN
#   investment/NN
#   in/IN
#   order/NN
#   to/TO
#   reclaim/VB
#   a/DT
#   high/JJ
#   growth/NN
#   trajectory/NN
#   ./.
#   ''/''
#   In/IN
#   addition/NN
#   ,/,
#   experts/NNS
#   cited/VBD
#   (GPE India/NNP Inc/NNP)
#   's/POS
#   massive/JJ
#   shift/NN
#   to/TO
#   e-com/JJ
#   ,/,
#   acceptance/NN
#   of/IN
#   higher/JJR
#   safety/NN
#   standards/NNS
#   and/CC
#   inculcation/NN
#   of/IN
#   efficiency/NN
#   boosting/VBG
#   measures/NNS
#   as/IN
#   other/JJ
#   notable/JJ
#   trends/NNS
#   during/IN
#   this/DT
#   historic/JJ
#   period/NN
#   ./.
#   (ORGANIZATION ALSO/NNP)
#   READ/NNP
#   |/NNP
#   No/NNP
#   corporate/JJ
#   can/MD
#   snatch/VB
#   away/RP
#   farmer/NN
#   's/POS
#   land/NN
#   till/NN
#   (PERSON Modi/NNP)
#   is/VBZ
#   PM/NNP
#   :/:
#   (PERSON Amit/NNP Shah/NNP Latest/NNP Business/NNP News/NNP))

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(content)
sent
# Out:
# [('(', '('),
#  ('Representational', 'NNP'),
#  ('image', 'NN'),
#  (')', ')'),
#  ('The', 'DT'),
#  ('covid-19', 'NN'),
#  ('induced', 'JJ'),
#  ('turmoil', 'NN'),
#  ('showed', 'VBD'),
#  ('weakness', 'NN'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('resilience', 'NN'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ("'s", 'POS'),
#  ('economy', 'NN'),
#  ('in', 'IN'),
#  ('2020', 'CD'),
#  (',', ','),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('GDP', 'NNP'),
#  ('recorded', 'VBD'),
#  ('abysmal', 'JJ'),
#  ('fall', 'NN'),
#  ('and', 'CC'),
#  ('breathtaking', 'JJ'),
#  ('recovery', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('economy', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('faced', 'VBD'),
#  ('a', 'DT'),
#  ('severe', 'JJ'),
#  ('slowdown', 'NN'),
#  ('prior', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('pandemic', 'NN'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('decimated', 'VBN'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('lockdown', 'NN'),
#  ('imposed', 'VBN'),
#  ('to', 'TO'),
#  ('curb', 'VB'),
#  ('the', 'DT'),
#  ('pandemic', 'NN'),
#  ("'s", 'POS'),
#  ('spread', 'NN'),
#  ('.', '.'),
#  ('Accordingly', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('GDP', 'NNP'),
#  ('contracted', 'VBN'),
#  ('by', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('23', 'CD'),
#  ('per', 'IN'),
#  ('cent', 'NN'),
#  ('in', 'IN'),
#  ('Q1FY21', 'NNP'),
#  ('.', '.'),
#  ('Nonetheless', 'NNP'),
#  (',', ','),
#  ('slow', 'JJ'),
#  ('tapering', 'NN'),
#  ('of', 'IN'),
#  ('mobility', 'NN'),
#  ('and', 'CC'),
#  ('lockdown', 'JJ'),
#  ('restrictions', 'NNS'),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('pent', 'NN'),
#  ('up', 'RB'),
#  ('demand', 'NN'),
#  ('narrowed', 'VBD'),
#  ('this', 'DT'),
#  ('contraction', 'NN'),
#  ('to', 'TO'),
#  ('under', 'IN'),
#  ('10', 'CD'),
#  ('per', 'IN'),
#  ('cent', 'NN'),
#  ('in', 'IN'),
#  ('Q2FY21', 'NNP'),
#  ('.', '.'),
#  ('Consequently', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('entered', 'VBD'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('technical', 'JJ'),
#  ('recession', 'NN'),
#  ('.', '.'),
#  ('Nevertheless', 'NNP'),
#  (',', ','),
#  ('festive', 'JJ'),
#  ('season', 'NN'),
#  (',', ','),
#  ('pent', 'NN'),
#  ('up', 'RB'),
#  ('demand', 'NN'),
#  ('and', 'CC'),
#  ('rise', 'NN'),
#  ('in', 'IN'),
#  ('discretionary', 'JJ'),
#  ('spending', 'NN'),
#  ('coupled', 'VBN'),
#  ('with', 'IN'),
#  ('massive', 'JJ'),
#  ('liquidity', 'NN'),
#  ('and', 'CC'),
#  ('government', 'NN'),
#  ('stimulus', 'NN'),
#  ('triggered', 'VBD'),
#  ('one', 'CD'),
#  ('the', 'DT'),
#  ('fastest', 'JJS'),
#  ('recovery', 'NN'),
#  ('pattern', 'NN'),
#  ('seen', 'VBN'),
#  ('anywhere', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('.', '.'),
#  ('ALSO', 'NNP'),
#  ('READ', 'NNP'),
#  ('|', 'NNP'),
#  ("'People", 'NNP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('be', 'VB'),
#  ('misled', 'VBN'),
#  ("'", 'POS'),
#  (':', ':'),
#  ('PM', 'NNP'),
#  ('Modi', 'NNP'),
#  ('rips', 'VBZ'),
#  ('into', 'IN'),
#  ('opposition', 'NN'),
#  ('for', 'IN'),
#  ('spreading', 'VBG'),
#  ('lies', 'NNS'),
#  ('on', 'IN'),
#  ('new', 'JJ'),
#  ('farm', 'NN'),
#  ('laws', 'NNS'),
#  ('Some', 'DT'),
#  ('economy', 'NN'),
#  ('watchers', 'NNS'),
#  ('described', 'VBD'),
#  ('the', 'DT'),
#  ('phenomenon', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ("'", "''"),
#  ('V', 'NNP'),
#  ("'", 'POS'),
#  ('shaped', 'JJ'),
#  ('recovery', 'NN'),
#  (',', ','),
#  ('whereas', 'NNS'),
#  (',', ','),
#  ('others', 'NNS'),
#  ('pointed', 'VBD'),
#  ('it', 'PRP'),
#  ('out', 'RP'),
#  ('as', 'IN'),
#  ("'", "''"),
#  ('U', 'NNP'),
#  ("'", 'POS'),
#  ('formation', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('restoration', 'NN'),
#  ('of', 'IN'),
#  ('economic', 'JJ'),
#  ('normalcy', 'NN'),
#  ('.', '.'),
#  ('All', 'DT'),
#  ('in', 'IN'),
#  ('all', 'DT'),
#  (',', ','),
#  ('sector', 'NN'),
#  ('after', 'IN'),
#  ('sector', 'NN'),
#  ('reported', 'VBD'),
#  ('sequential', 'JJ'),
#  ('growth', 'NN'),
#  ('with', 'IN'),
#  ('many', 'JJ'),
#  ('crossing', 'VBG'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  ('on', 'IN'),
#  ('year', 'NN'),
#  ('sales', 'NNS'),
#  ('and', 'CC'),
#  ('production', 'NN'),
#  ('levels', 'NNS'),
#  ('.', '.'),
#  ('Besides', 'IN'),
#  (',', ','),
#  ('various', 'JJ'),
#  ('factors', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('low', 'JJ'),
#  ('base', 'NN'),
#  (',', ','),
#  ('restocking', 'VBG'),
#  ('and', 'CC'),
#  ('higher', 'JJR'),
#  ('discretionary', 'JJ'),
#  ('spends', 'NNS'),
#  ('were', 'VBD'),
#  ('cited', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('heightened', 'JJ'),
#  ('economic', 'JJ'),
#  ('activity', 'NN'),
#  ('which', 'WDT'),
#  ('was', 'VBD'),
#  ('led', 'VBN'),
#  ('by', 'IN'),
#  ('agriculture', 'NN'),
#  (',', ','),
#  ('electricity', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('manufacturing', 'NN'),
#  ('sectors', 'NNS'),
#  ('.', '.'),
#  ('Even', 'RB'),
#  ('though', 'IN'),
#  ('cheaper', 'JJR'),
#  ('interest', 'NN'),
#  ('rates', 'NNS'),
#  ('helped', 'VBD'),
#  ('in', 'IN'),
#  ('spurring', 'VBG'),
#  ('consumption', 'NN'),
#  (',', ','),
#  ('other', 'JJ'),
#  ('vitals', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('lower', 'JJR'),
#  ('oil', 'NN'),
#  ('prices', 'NNS'),
#  (',', ','),
#  ('lesser', 'JJR'),
#  ('imports', 'NNS'),
#  ('and', 'CC'),
#  ('an', 'DT'),
#  ('accelerated', 'VBN'),
#  ('pick', 'NN'),
#  ('up', 'IN'),
#  ('of', 'IN'),
#  ('agricultural', 'JJ'),
#  ('and', 'CC'),
#  ('pharma', 'JJ'),
#  ('exports', 'NNS'),
#  ('added', 'VBD'),
#  ('positivity', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('economic', 'JJ'),
#  ('scene', 'NN'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('a', 'DT'),
#  ('healthy', 'JJ'),
#  ('monsoon', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ("'s", 'POS'),
#  ('festive', 'JJ'),
#  ('season', 'NN'),
#  ('coupled', 'VBN'),
#  ('with', 'IN'),
#  ("'unlock", 'NNP'),
#  ("'", 'POS'),
#  ('measures', 'NNS'),
#  ('opened', 'VBD'),
#  ('the', 'DT'),
#  ('floodgates', 'NNS'),
#  ('for', 'IN'),
#  ('retail', 'NN'),
#  (',', ','),
#  ('wholesale', 'JJ'),
#  ('and', 'CC'),
#  ('restocking', 'NN'),
#  (',', ','),
#  ('thereby', 'RB'),
#  (',', ','),
#  ('moving', 'VBG'),
#  ('the', 'DT'),
#  ('wheels', 'NNS'),
#  ('of', 'IN'),
#  ('economic', 'JJ'),
#  ('revival', 'NN'),
#  ('.', '.'),
#  ('Furthermore', 'NNP'),
#  (',', ','),
#  ('stock', 'NN'),
#  ('markets', 'NNS'),
#  ('boomed', 'VBD'),
#  (',', ','),
#  ('as', 'IN'),
#  ('macro-economic', 'JJ'),
#  ('data', 'NNS'),
#  ('and', 'CC'),
#  ('better-than-expected', 'JJ'),
#  ('quarterly', 'JJ'),
#  ('results', 'NNS'),
#  ('attracted', 'VBD'),
#  ('FIIs', 'NNP'),
#  ('with', 'IN'),
#  ('prospects', 'NNS'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('return', 'NN'),
#  (',', ','),
#  ('something', 'NN'),
#  ('that', 'WDT'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('missing', 'VBG'),
#  ('in', 'IN'),
#  ('other', 'JJ'),
#  ('asset', 'NN'),
#  ('classes', 'NNS'),
#  ('throughout', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('A', 'DT'),
#  ('tentative', 'JJ'),
#  ('recovery', 'NN'),
#  ('in', 'IN'),
#  ('volumes', 'NNS'),
#  ('is', 'VBZ'),
#  ('underway', 'RB'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('being', 'VBG'),
#  ('counteracted', 'VBN'),
#  ('by', 'IN'),
#  ('rising', 'VBG'),
#  ('raw', 'JJ'),
#  ('material', 'NN'),
#  ('prices', 'NNS'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('smaller', 'JJR'),
#  ('extent', 'NN'),
#  ('employee', 'NN'),
#  ('costs', 'NNS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('expect', 'VBP'),
#  ('the', 'DT'),
#  ('recovery', 'NN'),
#  ('to', 'TO'),
#  ('continue', 'VB'),
#  (',', ','),
#  ('albeit', 'IN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('mild', 'JJ'),
#  ('contraction', 'NN'),
#  ('in', 'IN'),
#  ('Q3', 'NNP'),
#  ('followed', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('muted', 'JJ'),
#  ('growth', 'NN'),
#  ('in', 'IN'),
#  ('Q4', 'NNP'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Aditi', 'NNP'),
#  ('Nayar', 'NNP'),
#  (',', ','),
#  ('Principal', 'NNP'),
#  ('Economist', 'NNP'),
#  (',', ','),
#  ('ICRA', 'NNP'),
#  ('.', '.'),
#  ('googletag.cmd.push', 'NN'),
#  ('(', '('),
#  ('function', 'NN'),
#  ('(', '('),
#  (')', ')'),
#  ('{', '('),
#  ('googletag.display', 'NN'),
#  ('(', '('),
#  ("'div-gpt-ad-1516086534511-1", 'JJ'),
#  ("'", "''"),
#  (')', ')'),
#  (';', ':'),
#  ('}', ')'),
#  (')', ')'),
#  (';', ':'),
#  ('On', 'IN'),
#  ('a', 'DT'),
#  ('sector', 'NN'),
#  ('specific', 'JJ'),
#  ('basis', 'NN'),
#  (',', ','),
#  ('while', 'IN'),
#  ('agriculture', 'NN'),
#  ('and', 'CC'),
#  ('allied', 'JJ'),
#  ('industries', 'NNS'),
#  ('pushed', 'VBD'),
#  ('the', 'DT'),
#  ('economy', 'NN'),
#  ('forward', 'RB'),
#  (',', ','),
#  ('manufacturing', 'VBG'),
#  ('too', 'RB'),
#  ('came', 'VBD'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('doldrums', 'NNS'),
#  ('even', 'RB'),
#  ('though', 'IN'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('dipped', 'VBN'),
#  ('slightly', 'RB'),
#  ('ever', 'RB'),
#  ('since', 'IN'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('service', 'NN'),
#  ('sector', 'NN'),
#  ("'s", 'POS'),
#  ('contribution', 'NN'),
#  ('was', 'VBD'),
#  ('lacking', 'VBG'),
#  ('in', 'IN'),
#  ('giving', 'VBG'),
#  ('a', 'DT'),
#  ('real', 'JJ'),
#  ('push', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('GDP', 'NNP'),
#  ('.', '.'),
#  ('Now', 'RB'),
#  ('with', 'IN'),
#  ('hopes', 'NNS'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('mass', 'NN'),
#  ('immunisation', 'NN'),
#  ('programme', 'NN'),
#  ('armed', 'VBN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('high', 'JJ'),
#  ('efficacy', 'NN'),
#  ('backed', 'VBD'),
#  ('vaccine', 'NN'),
#  (',', ','),
#  ('front', 'NN'),
#  ('and', 'CC'),
#  ('back', 'RB'),
#  ('end', 'NN'),
#  ('services', 'NNS'),
#  ('are', 'VBP'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('bounce', 'VB'),
#  ('back', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('next', 'JJ'),
#  ('leg', 'NN'),
#  ('of', 'IN'),
#  ('sequential', 'JJ'),
#  ('recovery', 'NN'),
#  ('may', 'MD'),
#  ('emerge', 'VB'),
#  ('from', 'IN'),
#  ('services', 'NNS'),
#  ('which', 'WDT'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('laggard', 'NN'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  (',', ','),
#  ('while', 'IN'),
#  ('government', 'NN'),
#  ('spending', 'NN'),
#  ('may', 'MD'),
#  ('also', 'RB'),
#  ('improve', 'VB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('margin', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('Emkay', 'NNP'),
#  ('Global', 'NNP'),
#  ("'s", 'POS'),
#  ('Lead', 'NNP'),
#  ('Economist', 'NNP'),
#  ('Madhavi', 'NNP'),
#  ('Arora', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('see', 'VBP'),
#  ('FY21', 'JJ'),
#  ('growth', 'NN'),
#  ('at', 'IN'),
#  ('(', '('),
#  ('-', ':'),
#  (')', ')'),
#  ('7.1', 'CD'),
#  ('per', 'IN'),
#  ('cent', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('mild', 'JJ'),
#  ('downward', 'JJ'),
#  ('bias', 'NN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('reckon', 'VBP'),
#  ('while', 'IN'),
#  ('2HFY21', 'CD'),
#  ('will', 'MD'),
#  ('see', 'VB'),
#  ('further', 'RB'),
#  ('pick', 'VB'),
#  ('up', 'RP'),
#  (',', ','),
#  ('sustaining', 'VBG'),
#  ('sequential', 'JJ'),
#  ('growth', 'NN'),
#  ('momentum', 'NN'),
#  ('beyond', 'IN'),
#  ('that', 'DT'),
#  ('will', 'MD'),
#  ('require', 'VB'),
#  ('easing', 'VBG'),
#  ('domestic', 'JJ'),
#  ('structural', 'JJ'),
#  ('overhang', 'NN'),
#  (',', ','),
#  ('continued', 'VBD'),
#  ('innovative', 'JJ'),
#  ('policy', 'NN'),
#  ('support', 'NN'),
#  ('and', 'CC'),
#  ('better', 'JJR'),
#  ('global', 'JJ'),
#  ('backdrop', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('she', 'PRP'),
#  ('added', 'VBD'),
#  ('.', '.'),
#  ('Apart', 'RB'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('spending', 'NN'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('private', 'JJ'),
#  ('final', 'JJ'),
#  ('consumption', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('savings', 'NNS'),
#  ('backed', 'VBD'),
#  ('discretionary', 'JJ'),
#  ('spends', 'NNS'),
#  ('of', 'IN'),
#  ('common', 'JJ'),
#  ('households', 'NNS'),
#  ('that', 'WDT'),
#  ('came', 'VBD'),
#  ('in', 'IN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('saviour', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('economy', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('believe', 'VBP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('accumulated', 'JJ'),
#  ('savings', 'NNS'),
#  ('of', 'IN'),
#  ('particularly', 'RB'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('salaried', 'JJ'),
#  ('class', 'NN'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('7-8', 'JJ'),
#  ('months', 'NNS'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('limited', 'JJ'),
#  ('expenses', 'NNS'),
#  ('on', 'IN'),
#  ('travel', 'NN'),
#  ('and', 'CC'),
#  ('entertainment', 'NN'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('partly', 'RB'),
#  ('diverted', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('purchase', 'NN'),
#  ('of', 'IN'),
#  ('vehicles', 'NNS'),
#  ('and', 'CC'),
#  ('consumer', 'NN'),
#  ('durables', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('Acuite', 'NNP'),
#  ('Ratings', 'NNP'),
#  ('&', 'CC'),
#  ('Research', 'NNP'),
#  ('Chief', 'NNP'),
#  ('Analytical', 'NNP'),
#  ('Officer', 'NNP'),
#  ('Suman', 'NNP'),
#  ('Chowdhury', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('already', 'RB'),
#  ('reflected', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('uptick', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('demand', 'NN'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('products', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('pent', 'NN'),
#  ('up', 'RB'),
#  ('demand', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('availability', 'NN'),
#  ('of', 'IN'),
#  ('higher', 'JJR'),
#  ('savings', 'NNS'),
#  (',', ','),
#  ('therefore', 'RB'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('drive', 'VB'),
#  ('consumption', 'NN'),
#  ('demand', 'NN'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('1-2', 'JJ'),
#  ('quarters', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('Chowdhury', 'NNP'),
#  ('added', 'VBD'),
#  ('.', '.'),
#  ('Other', 'JJ'),
#  ('than', 'IN'),
#  ('stimulus', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Centre', 'NNP'),
#  ("'s", 'POS'),
#  ('structural', 'JJ'),
#  ('reforms', 'NNS'),
#  (',', ','),
#  ('focus', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('manufacturing', 'NN'),
#  ('sector', 'NN'),
#  ('and', 'CC'),
#  ('inflow', 'NN'),
#  ('of', 'IN'),
#  ('FDI', 'NNP'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('are', 'VBP'),
#  ('likely', 'JJ'),
#  ('to', 'TO'),
#  ('hasten', 'VB'),
#  ('the', 'DT'),
#  ('pace', 'NN'),
#  ('of', 'IN'),
#  ('economic', 'JJ'),
#  ('recovery', 'NN'),
#  ('.', '.'),
#  ('According', 'VBG'),
#  ('to', 'TO'),
#  ('Brickwork', 'NNP'),
#  ('Ratings', 'NNP'),
#  ("'", 'POS'),
#  ('Chief', 'NNP'),
#  ('Economic', 'NNP'),
#  ('Adviser', 'NNP'),
#  ('M.', 'NNP'),
#  ('Govinda', 'NNP'),
#  ('Rao', 'NNP'),
#  (':', ':'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('economy', 'NN'),
#  ('will', 'MD'),
#  ('continue', 'VB'),
#  ('to', 'TO'),
#  ('recover', 'VB'),
#  ('as', 'IN'),
#  ('restrictions', 'NNS'),
#  ('are', 'VBP'),
#  ('relaxed', 'JJ'),
#  ('and', 'CC'),
#  ('capacity', 'NN'),
#  ('utilisation', 'NN'),
#  ('improves', 'VBZ'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('important', 'JJ'),
#  ('to', 'TO'),
#  ('undertake', 'VB'),
#  ('structural', 'JJ'),
#  ('reforms', 'NNS'),
#  ('to', 'TO'),
#  ('accelerate', 'VB'),
#  ('the', 'DT'),
#  ('pace', 'NN'),
#  ('of', 'IN'),
#  ('investment', 'NN'),
#  ('in', 'IN'),
#  ('order', 'NN'),
#  ('to', 'TO'),
#  ('reclaim', 'VB'),
#  ('a', 'DT'),
#  ('high', 'JJ'),
#  ('growth', 'NN'),
#  ('trajectory', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  (',', ','),
#  ('experts', 'NNS'),
#  ('cited', 'VBD'),
#  ('India', 'NNP'),
#  ('Inc', 'NNP'),
#  ("'s", 'POS'),
#  ('massive', 'JJ'),
#  ('shift', 'NN'),
#  ('to', 'TO'),
#  ('e-com', 'JJ'),
#  (',', ','),
#  ('acceptance', 'NN'),
#  ('of', 'IN'),
#  ('higher', 'JJR'),
#  ('safety', 'NN'),
#  ('standards', 'NNS'),
#  ('and', 'CC'),
#  ('inculcation', 'NN'),
#  ('of', 'IN'),
#  ('efficiency', 'NN'),
#  ('boosting', 'VBG'),
#  ('measures', 'NNS'),
#  ('as', 'IN'),
#  ('other', 'JJ'),
#  ('notable', 'JJ'),
#  ('trends', 'NNS'),
#  ('during', 'IN'),
#  ('this', 'DT'),
#  ('historic', 'JJ'),
#  ('period', 'NN'),
#  ('.', '.'),
#  ('ALSO', 'NNP'),
#  ('READ', 'NNP'),
#  ('|', 'NNP'),
#  ('No', 'NNP'),
#  ('corporate', 'JJ'),
#  ('can', 'MD'),
#  ('snatch', 'VB'),
#  ('away', 'RP'),
#  ('farmer', 'NN'),
#  ("'s", 'POS'),
#  ('land', 'NN'),
#  ('till', 'NN'),
#  ('Modi', 'NNP'),
#  ('is', 'VBZ'),
#  ('PM', 'NNP'),
#  (':', ':'),
#  ('Amit', 'NNP'),
#  ('Shah', 'NNP'),
#  ('Latest', 'NNP'),
#  ('Business', 'NNP'),
#  ('News', 'NNP')]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   (/(
#   Representational/NNP
#   (NP image/NN)
#   )/)
#   (NP The/DT covid-19/NN)
#   (NP induced/JJ turmoil/NN)
#   showed/VBD
#   (NP weakness/NN)
#   as/RB
#   well/RB
#   as/IN
#   (NP resilience/NN)
#   of/IN
#   India/NNP
#   's/POS
#   (NP economy/NN)
#   in/IN
#   2020/CD
#   ,/,
#   as/IN
#   (NP the/DT country/NN)
#   's/POS
#   GDP/NNP
#   recorded/VBD
#   (NP abysmal/JJ fall/NN)
#   and/CC
#   (NP breathtaking/JJ recovery/NN)
#   ./.
#   (NP The/DT economy/NN)
#   ,/,
#   which/WDT
#   faced/VBD
#   (NP a/DT severe/JJ slowdown/NN)
#   prior/RB
#   to/TO
#   (NP the/DT pandemic/NN)
#   ,/,
#   was/VBD
#   decimated/VBN
#   due/JJ
#   to/TO
#   (NP the/DT lockdown/NN)
#   imposed/VBN
#   to/TO
#   curb/VB
#   (NP the/DT pandemic/NN)
#   's/POS
#   (NP spread/NN)
#   ./.
#   Accordingly/RB
#   ,/,
#   (NP the/DT country/NN)
#   's/POS
#   GDP/NNP
#   contracted/VBN
#   by/IN
#   more/JJR
#   than/IN
#   23/CD
#   per/IN
#   (NP cent/NN)
#   in/IN
#   Q1FY21/NNP
#   ./.
#   Nonetheless/NNP
#   ,/,
#   (NP slow/JJ tapering/NN)
#   of/IN
#   (NP mobility/NN)
#   and/CC
#   lockdown/JJ
#   restrictions/NNS
#   along/IN
#   with/IN
#   (NP pent/NN)
#   up/RB
#   (NP demand/NN)
#   narrowed/VBD
#   (NP this/DT contraction/NN)
#   to/TO
#   under/IN
#   10/CD
#   per/IN
#   (NP cent/NN)
#   in/IN
#   Q2FY21/NNP
#   ./.
#   Consequently/RB
#   ,/,
#   (NP the/DT country/NN)
#   entered/VBD
#   into/IN
#   (NP a/DT technical/JJ recession/NN)
#   ./.
#   Nevertheless/NNP
#   ,/,
#   (NP festive/JJ season/NN)
#   ,/,
#   (NP pent/NN)
#   up/RB
#   (NP demand/NN)
#   and/CC
#   (NP rise/NN)
#   in/IN
#   (NP discretionary/JJ spending/NN)
#   coupled/VBN
#   with/IN
#   (NP massive/JJ liquidity/NN)
#   and/CC
#   (NP government/NN)
#   (NP stimulus/NN)
#   triggered/VBD
#   one/CD
#   the/DT
#   fastest/JJS
#   (NP recovery/NN)
#   (NP pattern/NN)
#   seen/VBN
#   anywhere/RB
#   in/IN
#   (NP the/DT world/NN)
#   ./.
#   ALSO/NNP
#   READ/NNP
#   |/NNP
#   'People/NNP
#   wo/MD
#   n't/RB
#   be/VB
#   misled/VBN
#   '/POS
#   :/:
#   PM/NNP
#   Modi/NNP
#   rips/VBZ
#   into/IN
#   (NP opposition/NN)
#   for/IN
#   spreading/VBG
#   lies/NNS
#   on/IN
#   (NP new/JJ farm/NN)
#   laws/NNS
#   (NP Some/DT economy/NN)
#   watchers/NNS
#   described/VBD
#   (NP the/DT phenomenon/NN)
#   as/IN
#   a/DT
#   '/''
#   V/NNP
#   '/POS
#   (NP shaped/JJ recovery/NN)
#   ,/,
#   whereas/NNS
#   ,/,
#   others/NNS
#   pointed/VBD
#   it/PRP
#   out/RP
#   as/IN
#   '/''
#   U/NNP
#   '/POS
#   (NP formation/NN)
#   for/IN
#   (NP the/DT restoration/NN)
#   of/IN
#   (NP economic/JJ normalcy/NN)
#   ./.
#   All/DT
#   in/IN
#   all/DT
#   ,/,
#   (NP sector/NN)
#   after/IN
#   (NP sector/NN)
#   reported/VBD
#   (NP sequential/JJ growth/NN)
#   with/IN
#   many/JJ
#   crossing/VBG
#   (NP the/DT year/NN)
#   on/IN
#   (NP year/NN)
#   sales/NNS
#   and/CC
#   (NP production/NN)
#   levels/NNS
#   ./.
#   Besides/IN
#   ,/,
#   various/JJ
#   factors/NNS
#   such/JJ
#   as/IN
#   (NP a/DT low/JJ base/NN)
#   ,/,
#   restocking/VBG
#   and/CC
#   higher/JJR
#   discretionary/JJ
#   spends/NNS
#   were/VBD
#   cited/VBN
#   for/IN
#   (NP the/DT heightened/JJ economic/JJ activity/NN)
#   which/WDT
#   was/VBD
#   led/VBN
#   by/IN
#   (NP agriculture/NN)
#   ,/,
#   (NP electricity/NN)
#   and/CC
#   (NP the/DT manufacturing/NN)
#   sectors/NNS
#   ./.
#   Even/RB
#   though/IN
#   cheaper/JJR
#   (NP interest/NN)
#   rates/NNS
#   helped/VBD
#   in/IN
#   spurring/VBG
#   (NP consumption/NN)
#   ,/,
#   other/JJ
#   vitals/NNS
#   such/JJ
#   as/IN
#   lower/JJR
#   (NP oil/NN)
#   prices/NNS
#   ,/,
#   lesser/JJR
#   imports/NNS
#   and/CC
#   an/DT
#   accelerated/VBN
#   (NP pick/NN)
#   up/IN
#   of/IN
#   agricultural/JJ
#   and/CC
#   pharma/JJ
#   exports/NNS
#   added/VBD
#   (NP positivity/NN)
#   to/TO
#   (NP the/DT economic/JJ scene/NN)
#   ./.
#   After/IN
#   (NP a/DT healthy/JJ monsoon/NN)
#   ,/,
#   (NP the/DT country/NN)
#   's/POS
#   (NP festive/JJ season/NN)
#   coupled/VBN
#   with/IN
#   'unlock/NNP
#   '/POS
#   measures/NNS
#   opened/VBD
#   the/DT
#   floodgates/NNS
#   for/IN
#   (NP retail/NN)
#   ,/,
#   wholesale/JJ
#   and/CC
#   (NP restocking/NN)
#   ,/,
#   thereby/RB
#   ,/,
#   moving/VBG
#   the/DT
#   wheels/NNS
#   of/IN
#   (NP economic/JJ revival/NN)
#   ./.
#   Furthermore/NNP
#   ,/,
#   (NP stock/NN)
#   markets/NNS
#   boomed/VBD
#   ,/,
#   as/IN
#   macro-economic/JJ
#   data/NNS
#   and/CC
#   better-than-expected/JJ
#   quarterly/JJ
#   results/NNS
#   attracted/VBD
#   FIIs/NNP
#   with/IN
#   prospects/NNS
#   of/IN
#   (NP a/DT return/NN)
#   ,/,
#   (NP something/NN)
#   that/WDT
#   has/VBZ
#   been/VBN
#   missing/VBG
#   in/IN
#   (NP other/JJ asset/NN)
#   classes/NNS
#   throughout/IN
#   (NP the/DT year/NN)
#   ./.
#   ``/``
#   (NP A/DT tentative/JJ recovery/NN)
#   in/IN
#   volumes/NNS
#   is/VBZ
#   underway/RB
#   ,/,
#   which/WDT
#   is/VBZ
#   being/VBG
#   counteracted/VBN
#   by/IN
#   rising/VBG
#   (NP raw/JJ material/NN)
#   prices/NNS
#   and/CC
#   to/TO
#   a/DT
#   smaller/JJR
#   (NP extent/NN)
#   (NP employee/NN)
#   costs/NNS
#   ./.
#   We/PRP
#   expect/VBP
#   (NP the/DT recovery/NN)
#   to/TO
#   continue/VB
#   ,/,
#   albeit/IN
#   with/IN
#   (NP a/DT mild/JJ contraction/NN)
#   in/IN
#   Q3/NNP
#   followed/VBN
#   by/IN
#   (NP a/DT muted/JJ growth/NN)
#   in/IN
#   Q4/NNP
#   ,/,
#   ''/''
#   said/VBD
#   Aditi/NNP
#   Nayar/NNP
#   ,/,
#   Principal/NNP
#   Economist/NNP
#   ,/,
#   ICRA/NNP
#   ./.
#   (NP googletag.cmd.push/NN)
#   (/(
#   (NP function/NN)
#   (/(
#   )/)
#   {/(
#   (NP googletag.display/NN)
#   (/(
#   'div-gpt-ad-1516086534511-1/JJ
#   '/''
#   )/)
#   ;/:
#   }/)
#   )/)
#   ;/:
#   On/IN
#   (NP a/DT sector/NN)
#   (NP specific/JJ basis/NN)
#   ,/,
#   while/IN
#   (NP agriculture/NN)
#   and/CC
#   allied/JJ
#   industries/NNS
#   pushed/VBD
#   (NP the/DT economy/NN)
#   forward/RB
#   ,/,
#   manufacturing/VBG
#   too/RB
#   came/VBD
#   out/IN
#   of/IN
#   its/PRP$
#   doldrums/NNS
#   even/RB
#   though/IN
#   it/PRP
#   has/VBZ
#   dipped/VBN
#   slightly/RB
#   ever/RB
#   since/IN
#   ./.
#   However/RB
#   ,/,
#   (NP the/DT service/NN)
#   (NP sector/NN)
#   's/POS
#   (NP contribution/NN)
#   was/VBD
#   lacking/VBG
#   in/IN
#   giving/VBG
#   (NP a/DT real/JJ push/NN)
#   to/TO
#   the/DT
#   GDP/NNP
#   ./.
#   Now/RB
#   with/IN
#   hopes/NNS
#   of/IN
#   (NP a/DT mass/NN)
#   (NP immunisation/NN)
#   (NP programme/NN)
#   armed/VBN
#   with/IN
#   (NP a/DT high/JJ efficacy/NN)
#   backed/VBD
#   (NP vaccine/NN)
#   ,/,
#   (NP front/NN)
#   and/CC
#   back/RB
#   (NP end/NN)
#   services/NNS
#   are/VBP
#   expected/VBN
#   to/TO
#   bounce/VB
#   back/RB
#   ./.
#   ``/``
#   (NP The/DT next/JJ leg/NN)
#   of/IN
#   (NP sequential/JJ recovery/NN)
#   may/MD
#   emerge/VB
#   from/IN
#   services/NNS
#   which/WDT
#   has/VBZ
#   been/VBN
#   (NP a/DT laggard/NN)
#   so/RB
#   far/RB
#   ,/,
#   while/IN
#   (NP government/NN)
#   (NP spending/NN)
#   may/MD
#   also/RB
#   improve/VB
#   at/IN
#   (NP the/DT margin/NN)
#   ,/,
#   ''/''
#   Emkay/NNP
#   Global/NNP
#   's/POS
#   Lead/NNP
#   Economist/NNP
#   Madhavi/NNP
#   Arora/NNP
#   said/VBD
#   ./.
#   ``/``
#   We/PRP
#   see/VBP
#   (NP FY21/JJ growth/NN)
#   at/IN
#   (/(
#   -/:
#   )/)
#   7.1/CD
#   per/IN
#   (NP cent/NN)
#   with/IN
#   (NP a/DT mild/JJ downward/JJ bias/NN)
#   ./.
#   We/PRP
#   reckon/VBP
#   while/IN
#   2HFY21/CD
#   will/MD
#   see/VB
#   further/RB
#   pick/VB
#   up/RP
#   ,/,
#   sustaining/VBG
#   (NP sequential/JJ growth/NN)
#   (NP momentum/NN)
#   beyond/IN
#   that/DT
#   will/MD
#   require/VB
#   easing/VBG
#   (NP domestic/JJ structural/JJ overhang/NN)
#   ,/,
#   continued/VBD
#   (NP innovative/JJ policy/NN)
#   (NP support/NN)
#   and/CC
#   better/JJR
#   (NP global/JJ backdrop/NN)
#   ,/,
#   ''/''
#   she/PRP
#   added/VBD
#   ./.
#   Apart/RB
#   from/IN
#   (NP the/DT government/NN)
#   (NP spending/NN)
#   or/CC
#   (NP the/DT private/JJ final/JJ consumption/NN)
#   ,/,
#   it/PRP
#   was/VBD
#   savings/NNS
#   backed/VBD
#   discretionary/JJ
#   spends/NNS
#   of/IN
#   common/JJ
#   households/NNS
#   that/WDT
#   came/VBD
#   in/IN
#   as/IN
#   (NP a/DT saviour/NN)
#   for/IN
#   (NP the/DT economy/NN)
#   ./.
#   ``/``
#   We/PRP
#   believe/VBP
#   that/IN
#   the/DT
#   accumulated/JJ
#   savings/NNS
#   of/IN
#   particularly/RB
#   (NP the/DT Indian/JJ salaried/JJ class/NN)
#   over/IN
#   the/DT
#   last/JJ
#   7-8/JJ
#   months/NNS
#   due/JJ
#   to/TO
#   limited/JJ
#   expenses/NNS
#   on/IN
#   (NP travel/NN)
#   and/CC
#   (NP entertainment/NN)
#   will/MD
#   get/VB
#   partly/RB
#   diverted/VBN
#   to/TO
#   (NP the/DT purchase/NN)
#   of/IN
#   vehicles/NNS
#   and/CC
#   (NP consumer/NN)
#   durables/NNS
#   ,/,
#   ''/''
#   Acuite/NNP
#   Ratings/NNP
#   &/CC
#   Research/NNP
#   Chief/NNP
#   Analytical/NNP
#   Officer/NNP
#   Suman/NNP
#   Chowdhury/NNP
#   said/VBD
#   ./.
#   ``/``
#   This/DT
#   is/VBZ
#   already/RB
#   reflected/VBN
#   in/IN
#   (NP the/DT uptick/NN)
#   in/IN
#   (NP the/DT demand/NN)
#   of/IN
#   these/DT
#   products/NNS
#   ./.
#   (NP The/DT pent/NN)
#   up/RB
#   (NP demand/NN)
#   and/CC
#   (NP the/DT availability/NN)
#   of/IN
#   higher/JJR
#   savings/NNS
#   ,/,
#   therefore/RB
#   is/VBZ
#   expected/VBN
#   to/TO
#   drive/VB
#   (NP consumption/NN)
#   (NP demand/NN)
#   over/IN
#   the/DT
#   next/JJ
#   1-2/JJ
#   quarters/NNS
#   ,/,
#   ''/''
#   Chowdhury/NNP
#   added/VBD
#   ./.
#   Other/JJ
#   than/IN
#   (NP stimulus/NN)
#   ,/,
#   the/DT
#   Centre/NNP
#   's/POS
#   structural/JJ
#   reforms/NNS
#   ,/,
#   (NP focus/NN)
#   on/IN
#   (NP the/DT manufacturing/NN)
#   (NP sector/NN)
#   and/CC
#   (NP inflow/NN)
#   of/IN
#   FDI/NNP
#   into/IN
#   (NP the/DT country/NN)
#   are/VBP
#   likely/JJ
#   to/TO
#   hasten/VB
#   (NP the/DT pace/NN)
#   of/IN
#   (NP economic/JJ recovery/NN)
#   ./.
#   According/VBG
#   to/TO
#   Brickwork/NNP
#   Ratings/NNP
#   '/POS
#   Chief/NNP
#   Economic/NNP
#   Adviser/NNP
#   M./NNP
#   Govinda/NNP
#   Rao/NNP
#   :/:
#   ``/``
#   (NP The/DT economy/NN)
#   will/MD
#   continue/VB
#   to/TO
#   recover/VB
#   as/IN
#   restrictions/NNS
#   are/VBP
#   relaxed/JJ
#   and/CC
#   (NP capacity/NN)
#   (NP utilisation/NN)
#   improves/VBZ
#   ./.
#   It/PRP
#   is/VBZ
#   important/JJ
#   to/TO
#   undertake/VB
#   structural/JJ
#   reforms/NNS
#   to/TO
#   accelerate/VB
#   (NP the/DT pace/NN)
#   of/IN
#   (NP investment/NN)
#   in/IN
#   (NP order/NN)
#   to/TO
#   reclaim/VB
#   (NP a/DT high/JJ growth/NN)
#   (NP trajectory/NN)
#   ./.
#   ''/''
#   In/IN
#   (NP addition/NN)
#   ,/,
#   experts/NNS
#   cited/VBD
#   India/NNP
#   Inc/NNP
#   's/POS
#   (NP massive/JJ shift/NN)
#   to/TO
#   e-com/JJ
#   ,/,
#   (NP acceptance/NN)
#   of/IN
#   higher/JJR
#   (NP safety/NN)
#   standards/NNS
#   and/CC
#   (NP inculcation/NN)
#   of/IN
#   (NP efficiency/NN)
#   boosting/VBG
#   measures/NNS
#   as/IN
#   other/JJ
#   notable/JJ
#   trends/NNS
#   during/IN
#   (NP this/DT historic/JJ period/NN)
#   ./.
#   ALSO/NNP
#   READ/NNP
#   |/NNP
#   No/NNP
#   corporate/JJ
#   can/MD
#   snatch/VB
#   away/RP
#   (NP farmer/NN)
#   's/POS
#   (NP land/NN)
#   (NP till/NN)
#   Modi/NNP
#   is/VBZ
#   PM/NNP
#   :/:
#   Amit/NNP
#   Shah/NNP
#   Latest/NNP
#   Business/NNP
#   News/NNP)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('(', '(', 'O'),
#  ('Representational', 'NNP', 'O'),
#  ('image', 'NN', 'B-NP'),
#  (')', ')', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('covid-19', 'NN', 'I-NP'),
#  ('induced', 'JJ', 'B-NP'),
#  ('turmoil', 'NN', 'I-NP'),
#  ('showed', 'VBD', 'O'),
#  ('weakness', 'NN', 'B-NP'),
#  ('as', 'RB', 'O'),
#  ('well', 'RB', 'O'),
#  ('as', 'IN', 'O'),
#  ('resilience', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('India', 'NNP', 'O'),
#  ("'s", 'POS', 'O'),
#  ('economy', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('2020', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('as', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('country', 'NN', 'I-NP'),
#  ("'s", 'POS', 'O'),
#  ('GDP', 'NNP', 'O'),
#  ('recorded', 'VBD', 'O'),
#  ('abysmal', 'JJ', 'B-NP'),
#  ('fall', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('breathtaking', 'JJ', 'B-NP'),
#  ('recovery', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('economy', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('faced', 'VBD', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('severe', 'JJ', 'I-NP'),
#  ('slowdown', 'NN', 'I-NP'),
#  ('prior', 'RB', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pandemic', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('was', 'VBD', 'O'),
#  ('decimated', 'VBN', 'O'),
#  ('due', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('lockdown', 'NN', 'I-NP'),
#  ('imposed', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('curb', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pandemic', 'NN', 'I-NP'),
#  ("'s", 'POS', 'O'),
#  ('spread', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Accordingly', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('country', 'NN', 'I-NP'),
#  ("'s", 'POS', 'O'),
#  ('GDP', 'NNP', 'O'),
#  ('contracted', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('more', 'JJR', 'O'),
#  ('than', 'IN', 'O'),
#  ('23', 'CD', 'O'),
#  ('per', 'IN', 'O'),
#  ('cent', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('Q1FY21', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Nonetheless', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('slow', 'JJ', 'B-NP'),
#  ('tapering', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('mobility', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('lockdown', 'JJ', 'O'),
#  ('restrictions', 'NNS', 'O'),
#  ('along', 'IN', 'O'),
#  ('with', 'IN', 'O'),
#  ('pent', 'NN', 'B-NP'),
#  ('up', 'RB', 'O'),
#  ('demand', 'NN', 'B-NP'),
#  ('narrowed', 'VBD', 'O'),
#  ('this', 'DT', 'B-NP'),
#  ('contraction', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('under', 'IN', 'O'),
#  ('10', 'CD', 'O'),
#  ('per', 'IN', 'O'),
#  ('cent', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('Q2FY21', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Consequently', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('country', 'NN', 'I-NP'),
#  ('entered', 'VBD', 'O'),
#  ('into', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('technical', 'JJ', 'I-NP'),
#  ('recession', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Nevertheless', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('festive', 'JJ', 'B-NP'),
#  ('season', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('pent', 'NN', 'B-NP'),
#  ('up', 'RB', 'O'),
#  ('demand', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('rise', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('discretionary', 'JJ', 'B-NP'),
#  ('spending', 'NN', 'I-NP'),
#  ('coupled', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('massive', 'JJ', 'B-NP'),
#  ('liquidity', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('government', 'NN', 'B-NP'),
#  ('stimulus', 'NN', 'B-NP'),
#  ('triggered', 'VBD', 'O'),
#  ('one', 'CD', 'O'),
#  ('the', 'DT', 'O'),
#  ('fastest', 'JJS', 'O'),
#  ('recovery', 'NN', 'B-NP'),
#  ('pattern', 'NN', 'B-NP'),
#  ('seen', 'VBN', 'O'),
#  ('anywhere', 'RB', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('world', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('ALSO', 'NNP', 'O'),
#  ('READ', 'NNP', 'O'),
#  ('|', 'NNP', 'O'),
#  ("'People", 'NNP', 'O'),
#  ('wo', 'MD', 'O'),
#  ("n't", 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('misled', 'VBN', 'O'),
#  ("'", 'POS', 'O'),
#  (':', ':', 'O'),
#  ('PM', 'NNP', 'O'),
#  ('Modi', 'NNP', 'O'),
#  ('rips', 'VBZ', 'O'),
#  ('into', 'IN', 'O'),
#  ('opposition', 'NN', 'B-NP'),
#  ('for', 'IN', 'O'),
#  ('spreading', 'VBG', 'O'),
#  ('lies', 'NNS', 'O'),
#  ('on', 'IN', 'O'),
#  ('new', 'JJ', 'B-NP'),
#  ('farm', 'NN', 'I-NP'),
#  ('laws', 'NNS', 'O'),
#  ('Some', 'DT', 'B-NP'),
#  ('economy', 'NN', 'I-NP'),
#  ('watchers', 'NNS', 'O'),
#  ('described', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('phenomenon', 'NN', 'I-NP'),
#  ('as', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ("'", "''", 'O'),
#  ('V', 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('shaped', 'JJ', 'B-NP'),
#  ('recovery', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('whereas', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('others', 'NNS', 'O'),
#  ('pointed', 'VBD', 'O'),
#  ('it', 'PRP', 'O'),
#  ('out', 'RP', 'O'),
#  ('as', 'IN', 'O'),
#  ("'", "''", 'O'),
#  ('U', 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('formation', 'NN', 'B-NP'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('restoration', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('economic', 'JJ', 'B-NP'),
#  ('normalcy', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('All', 'DT', 'O'),
#  ('in', 'IN', 'O'),
#  ('all', 'DT', 'O'),
#  (',', ',', 'O'),
#  ('sector', 'NN', 'B-NP'),
#  ('after', 'IN', 'O'),
#  ('sector', 'NN', 'B-NP'),
#  ('reported', 'VBD', 'O'),
#  ('sequential', 'JJ', 'B-NP'),
#  ('growth', 'NN', 'I-NP'),
#  ('with', 'IN', 'O'),
#  ('many', 'JJ', 'O'),
#  ('crossing', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('year', 'NN', 'I-NP'),
#  ('on', 'IN', 'O'),
#  ('year', 'NN', 'B-NP'),
#  ('sales', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('production', 'NN', 'B-NP'),
#  ('levels', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Besides', 'IN', 'O'),
#  (',', ',', 'O'),
#  ('various', 'JJ', 'O'),
#  ('factors', 'NNS', 'O'),
#  ('such', 'JJ', 'O'),
#  ('as', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('low', 'JJ', 'I-NP'),
#  ('base', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('restocking', 'VBG', 'O'),
#  ('and', 'CC', 'O'),
#  ('higher', 'JJR', 'O'),
#  ('discretionary', 'JJ', 'O'),
#  ('spends', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('cited', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('heightened', 'JJ', 'I-NP'),
#  ('economic', 'JJ', 'I-NP'),
#  ('activity', 'NN', 'I-NP'),
#  ('which', 'WDT', 'O'),
#  ('was', 'VBD', 'O'),
#  ('led', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('agriculture', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('electricity', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('manufacturing', 'NN', 'I-NP'),
#  ('sectors', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Even', 'RB', 'O'),
#  ('though', 'IN', 'O'),
#  ('cheaper', 'JJR', 'O'),
#  ('interest', 'NN', 'B-NP'),
#  ('rates', 'NNS', 'O'),
#  ('helped', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('spurring', 'VBG', 'O'),
#  ('consumption', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('other', 'JJ', 'O'),
#  ('vitals', 'NNS', 'O'),
#  ('such', 'JJ', 'O'),
#  ('as', 'IN', 'O'),
#  ('lower', 'JJR', 'O'),
#  ('oil', 'NN', 'B-NP'),
#  ('prices', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('lesser', 'JJR', 'O'),
#  ('imports', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('an', 'DT', 'O'),
#  ('accelerated', 'VBN', 'O'),
#  ('pick', 'NN', 'B-NP'),
#  ('up', 'IN', 'O'),
#  ('of', 'IN', 'O'),
#  ('agricultural', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('pharma', 'JJ', 'O'),
#  ('exports', 'NNS', 'O'),
#  ('added', 'VBD', 'O'),
#  ('positivity', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('economic', 'JJ', 'I-NP'),
#  ('scene', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('After', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('healthy', 'JJ', 'I-NP'),
#  ('monsoon', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('country', 'NN', 'I-NP'),
#  ("'s", 'POS', 'O'),
#  ('festive', 'JJ', 'B-NP'),
#  ('season', 'NN', 'I-NP'),
#  ('coupled', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ("'unlock", 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('measures', 'NNS', 'O'),
#  ('opened', 'VBD', 'O'),
#  ('the', 'DT', 'O'),
#  ('floodgates', 'NNS', 'O'),
#  ('for', 'IN', 'O'),
#  ('retail', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('wholesale', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('restocking', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('thereby', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('moving', 'VBG', 'O'),
#  ('the', 'DT', 'O'),
#  ('wheels', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('economic', 'JJ', 'B-NP'),
#  ('revival', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Furthermore', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('stock', 'NN', 'B-NP'),
#  ('markets', 'NNS', 'O'),
#  ('boomed', 'VBD', 'O'),
#  (',', ',', 'O'),
#  ('as', 'IN', 'O'),
#  ('macro-economic', 'JJ', 'O'),
#  ('data', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('better-than-expected', 'JJ', 'O'),
#  ('quarterly', 'JJ', 'O'),
#  ('results', 'NNS', 'O'),
#  ('attracted', 'VBD', 'O'),
#  ('FIIs', 'NNP', 'O'),
#  ('with', 'IN', 'O'),
#  ('prospects', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('return', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('something', 'NN', 'B-NP'),
#  ('that', 'WDT', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('been', 'VBN', 'O'),
#  ('missing', 'VBG', 'O'),
#  ('in', 'IN', 'O'),
#  ('other', 'JJ', 'B-NP'),
#  ('asset', 'NN', 'I-NP'),
#  ('classes', 'NNS', 'O'),
#  ('throughout', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('year', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('``', '``', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('tentative', 'JJ', 'I-NP'),
#  ('recovery', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('volumes', 'NNS', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('underway', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('being', 'VBG', 'O'),
#  ('counteracted', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('rising', 'VBG', 'O'),
#  ('raw', 'JJ', 'B-NP'),
#  ('material', 'NN', 'I-NP'),
#  ('prices', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('to', 'TO', 'O'),
#  ('a', 'DT', 'O'),
#  ('smaller', 'JJR', 'O'),
#  ('extent', 'NN', 'B-NP'),
#  ('employee', 'NN', 'B-NP'),
#  ('costs', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('We', 'PRP', 'O'),
#  ('expect', 'VBP', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('recovery', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('continue', 'VB', 'O'),
#  (',', ',', 'O'),
#  ('albeit', 'IN', 'O'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('mild', 'JJ', 'I-NP'),
#  ('contraction', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('Q3', 'NNP', 'O'),
#  ('followed', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('muted', 'JJ', 'I-NP'),
#  ('growth', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('Q4', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ("''", "''", 'O'),
#  ('said', 'VBD', 'O'),
#  ('Aditi', 'NNP', 'O'),
#  ('Nayar', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Principal', 'NNP', 'O'),
#  ('Economist', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('ICRA', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('googletag.cmd.push', 'NN', 'B-NP'),
#  ('(', '(', 'O'),
#  ('function', 'NN', 'B-NP'),
#  ('(', '(', 'O'),
#  (')', ')', 'O'),
#  ('{', '(', 'O'),
#  ('googletag.display', 'NN', 'B-NP'),
#  ('(', '(', 'O'),
#  ("'div-gpt-ad-1516086534511-1", 'JJ', 'O'),
#  ("'", "''", 'O'),
#  (')', ')', 'O'),
#  (';', ':', 'O'),
#  ('}', ')', 'O'),
#  (')', ')', 'O'),
#  (';', ':', 'O'),
#  ('On', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('sector', 'NN', 'I-NP'),
#  ('specific', 'JJ', 'B-NP'),
#  ('basis', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('while', 'IN', 'O'),
#  ('agriculture', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('allied', 'JJ', 'O'),
#  ('industries', 'NNS', 'O'),
#  ('pushed', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('economy', 'NN', 'I-NP'),
#  ('forward', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('manufacturing', 'VBG', 'O'),
#  ('too', 'RB', 'O'),
#  ('came', 'VBD', 'O'),
#  ('out', 'IN', 'O'),
#  ('of', 'IN', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('doldrums', 'NNS', 'O'),
#  ('even', 'RB', 'O'),
#  ('though', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('dipped', 'VBN', 'O'),
#  ('slightly', 'RB', 'O'),
#  ('ever', 'RB', 'O'),
#  ('since', 'IN', 'O'),
#  ('.', '.', 'O'),
#  ('However', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('service', 'NN', 'I-NP'),
#  ('sector', 'NN', 'B-NP'),
#  ("'s", 'POS', 'O'),
#  ('contribution', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('lacking', 'VBG', 'O'),
#  ('in', 'IN', 'O'),
#  ('giving', 'VBG', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('real', 'JJ', 'I-NP'),
#  ('push', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'O'),
#  ('GDP', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Now', 'RB', 'O'),
#  ('with', 'IN', 'O'),
#  ('hopes', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('mass', 'NN', 'I-NP'),
#  ('immunisation', 'NN', 'B-NP'),
#  ('programme', 'NN', 'B-NP'),
#  ('armed', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('high', 'JJ', 'I-NP'),
#  ('efficacy', 'NN', 'I-NP'),
#  ('backed', 'VBD', 'O'),
#  ('vaccine', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('front', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('back', 'RB', 'O'),
#  ('end', 'NN', 'B-NP'),
#  ('services', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('expected', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('bounce', 'VB', 'O'),
#  ('back', 'RB', 'O'),
#  ('.', '.', 'O'),
#  ('``', '``', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('next', 'JJ', 'I-NP'),
#  ('leg', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('sequential', 'JJ', 'B-NP'),
#  ('recovery', 'NN', 'I-NP'),
#  ('may', 'MD', 'O'),
#  ('emerge', 'VB', 'O'),
#  ('from', 'IN', 'O'),
#  ('services', 'NNS', 'O'),
#  ('which', 'WDT', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('been', 'VBN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('laggard', 'NN', 'I-NP'),
#  ('so', 'RB', 'O'),
#  ('far', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('while', 'IN', 'O'),
#  ('government', 'NN', 'B-NP'),
#  ('spending', 'NN', 'B-NP'),
#  ('may', 'MD', 'O'),
#  ('also', 'RB', 'O'),
#  ('improve', 'VB', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('margin', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ("''", "''", 'O'),
#  ('Emkay', 'NNP', 'O'),
#  ('Global', 'NNP', 'O'),
#  ("'s", 'POS', 'O'),
#  ('Lead', 'NNP', 'O'),
#  ('Economist', 'NNP', 'O'),
#  ('Madhavi', 'NNP', 'O'),
#  ('Arora', 'NNP', 'O'),
#  ('said', 'VBD', 'O'),
#  ('.', '.', 'O'),
#  ('``', '``', 'O'),
#  ('We', 'PRP', 'O'),
#  ('see', 'VBP', 'O'),
#  ('FY21', 'JJ', 'B-NP'),
#  ('growth', 'NN', 'I-NP'),
#  ('at', 'IN', 'O'),
#  ('(', '(', 'O'),
#  ('-', ':', 'O'),
#  (')', ')', 'O'),
#  ('7.1', 'CD', 'O'),
#  ('per', 'IN', 'O'),
#  ('cent', 'NN', 'B-NP'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('mild', 'JJ', 'I-NP'),
#  ('downward', 'JJ', 'I-NP'),
#  ('bias', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('We', 'PRP', 'O'),
#  ('reckon', 'VBP', 'O'),
#  ('while', 'IN', 'O'),
#  ('2HFY21', 'CD', 'O'),
#  ('will', 'MD', 'O'),
#  ('see', 'VB', 'O'),
#  ('further', 'RB', 'O'),
#  ('pick', 'VB', 'O'),
#  ('up', 'RP', 'O'),
#  (',', ',', 'O'),
#  ('sustaining', 'VBG', 'O'),
#  ('sequential', 'JJ', 'B-NP'),
#  ('growth', 'NN', 'I-NP'),
#  ('momentum', 'NN', 'B-NP'),
#  ('beyond', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('will', 'MD', 'O'),
#  ('require', 'VB', 'O'),
#  ('easing', 'VBG', 'O'),
#  ('domestic', 'JJ', 'B-NP'),
#  ('structural', 'JJ', 'I-NP'),
#  ('overhang', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('continued', 'VBD', 'O'),
#  ('innovative', 'JJ', 'B-NP'),
#  ('policy', 'NN', 'I-NP'),
#  ('support', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('better', 'JJR', 'O'),
#  ('global', 'JJ', 'B-NP'),
#  ('backdrop', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ("''", "''", 'O'),
#  ('she', 'PRP', 'O'),
#  ('added', 'VBD', 'O'),
#  ('.', '.', 'O'),
#  ('Apart', 'RB', 'O'),
#  ('from', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('government', 'NN', 'I-NP'),
#  ('spending', 'NN', 'B-NP'),
#  ('or', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('private', 'JJ', 'I-NP'),
#  ('final', 'JJ', 'I-NP'),
#  ('consumption', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('it', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('savings', 'NNS', 'O'),
#  ('backed', 'VBD', 'O'),
#  ('discretionary', 'JJ', 'O'),
#  ('spends', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('common', 'JJ', 'O'),
#  ('households', 'NNS', 'O'),
#  ('that', 'WDT', 'O'),
#  ('came', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('as', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('saviour', 'NN', 'I-NP'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('economy', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('``', '``', 'O'),
#  ('We', 'PRP', 'O'),
#  ('believe', 'VBP', 'O'),
#  ('that', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('accumulated', 'JJ', 'O'),
#  ('savings', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('particularly', 'RB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('Indian', 'JJ', 'I-NP'),
#  ('salaried', 'JJ', 'I-NP'),
#  ('class', 'NN', 'I-NP'),
#  ('over', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('last', 'JJ', 'O'),
#  ('7-8', 'JJ', 'O'),
#  ('months', 'NNS', 'O'),
#  ('due', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('limited', 'JJ', 'O'),
#  ('expenses', 'NNS', 'O'),
#  ('on', 'IN', 'O'),
#  ('travel', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('entertainment', 'NN', 'B-NP'),
#  ('will', 'MD', 'O'),
#  ('get', 'VB', 'O'),
#  ('partly', 'RB', 'O'),
#  ('diverted', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('purchase', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('vehicles', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('consumer', 'NN', 'B-NP'),
#  ('durables', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ("''", "''", 'O'),
#  ('Acuite', 'NNP', 'O'),
#  ('Ratings', 'NNP', 'O'),
#  ('&', 'CC', 'O'),
#  ('Research', 'NNP', 'O'),
#  ('Chief', 'NNP', 'O'),
#  ('Analytical', 'NNP', 'O'),
#  ('Officer', 'NNP', 'O'),
#  ('Suman', 'NNP', 'O'),
#  ('Chowdhury', 'NNP', 'O'),
#  ('said', 'VBD', 'O'),
#  ('.', '.', 'O'),
#  ('``', '``', 'O'),
#  ('This', 'DT', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('already', 'RB', 'O'),
#  ('reflected', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('uptick', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('demand', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('these', 'DT', 'O'),
#  ('products', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('pent', 'NN', 'I-NP'),
#  ('up', 'RB', 'O'),
#  ('demand', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('availability', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('higher', 'JJR', 'O'),
#  ('savings', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('therefore', 'RB', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('expected', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('drive', 'VB', 'O'),
#  ('consumption', 'NN', 'B-NP'),
#  ('demand', 'NN', 'B-NP'),
#  ('over', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('next', 'JJ', 'O'),
#  ('1-2', 'JJ', 'O'),
#  ('quarters', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ("''", "''", 'O'),
#  ('Chowdhury', 'NNP', 'O'),
#  ('added', 'VBD', 'O'),
#  ('.', '.', 'O'),
#  ('Other', 'JJ', 'O'),
#  ('than', 'IN', 'O'),
#  ('stimulus', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'O'),
#  ('Centre', 'NNP', 'O'),
#  ("'s", 'POS', 'O'),
#  ('structural', 'JJ', 'O'),
#  ('reforms', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('focus', 'NN', 'B-NP'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('manufacturing', 'NN', 'I-NP'),
#  ('sector', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('inflow', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('FDI', 'NNP', 'O'),
#  ('into', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('country', 'NN', 'I-NP'),
#  ('are', 'VBP', 'O'),
#  ('likely', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('hasten', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pace', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('economic', 'JJ', 'B-NP'),
#  ('recovery', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('According', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('Brickwork', 'NNP', 'O'),
#  ('Ratings', 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('Chief', 'NNP', 'O'),
#  ('Economic', 'NNP', 'O'),
#  ('Adviser', 'NNP', 'O'),
#  ('M.', 'NNP', 'O'),
#  ('Govinda', 'NNP', 'O'),
#  ('Rao', 'NNP', 'O'),
#  (':', ':', 'O'),
#  ('``', '``', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('economy', 'NN', 'I-NP'),
#  ('will', 'MD', 'O'),
#  ('continue', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('recover', 'VB', 'O'),
#  ('as', 'IN', 'O'),
#  ('restrictions', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('relaxed', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('capacity', 'NN', 'B-NP'),
#  ('utilisation', 'NN', 'B-NP'),
#  ('improves', 'VBZ', 'O'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('important', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('undertake', 'VB', 'O'),
#  ('structural', 'JJ', 'O'),
#  ('reforms', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('accelerate', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pace', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('investment', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('order', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('reclaim', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('high', 'JJ', 'I-NP'),
#  ('growth', 'NN', 'I-NP'),
#  ('trajectory', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ("''", "''", 'O'),
#  ('In', 'IN', 'O'),
#  ('addition', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('experts', 'NNS', 'O'),
#  ('cited', 'VBD', 'O'),
#  ('India', 'NNP', 'O'),
#  ('Inc', 'NNP', 'O'),
#  ("'s", 'POS', 'O'),
#  ('massive', 'JJ', 'B-NP'),
#  ('shift', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('e-com', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('acceptance', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('higher', 'JJR', 'O'),
#  ('safety', 'NN', 'B-NP'),
#  ('standards', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('inculcation', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('efficiency', 'NN', 'B-NP'),
#  ('boosting', 'VBG', 'O'),
#  ('measures', 'NNS', 'O'),
#  ('as', 'IN', 'O'),
#  ('other', 'JJ', 'O'),
#  ('notable', 'JJ', 'O'),
#  ('trends', 'NNS', 'O'),
#  ('during', 'IN', 'O'),
#  ('this', 'DT', 'B-NP'),
#  ('historic', 'JJ', 'I-NP'),
#  ('period', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('ALSO', 'NNP', 'O'),
#  ('READ', 'NNP', 'O'),
#  ('|', 'NNP', 'O'),
#  ('No', 'NNP', 'O'),
#  ('corporate', 'JJ', 'O'),
#  ('can', 'MD', 'O'),
#  ('snatch', 'VB', 'O'),
#  ('away', 'RP', 'O'),
#  ('farmer', 'NN', 'B-NP'),
#  ("'s", 'POS', 'O'),
#  ('land', 'NN', 'B-NP'),
#  ('till', 'NN', 'B-NP'),
#  ('Modi', 'NNP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('PM', 'NNP', 'O'),
#  (':', ':', 'O'),
#  ('Amit', 'NNP', 'O'),
#  ('Shah', 'NNP', 'O'),
#  ('Latest', 'NNP', 'O'),
#  ('Business', 'NNP', 'O'),
#  ('News', 'NNP', 'O')]

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# C:\Users\ShubhamShukla\Anaconda3\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.5) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
doc = nlp(content)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('India', 'GPE'),
#  ('2020', 'DATE'),
#  ('more than 23', 'CARDINAL'),
#  ('Q1FY21', 'GPE'),
#  ('under 10 per cent', 'MONEY'),
#  ('Q2FY21', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('PM Modi', 'ORG'),
#  ('year', 'DATE'),
#  ('quarterly', 'DATE'),
#  ('the year', 'DATE'),
#  ('Q3', 'PERSON'),
#  ('Q4', 'PRODUCT'),
#  ('Aditi Nayar', 'PERSON'),
#  ('ICRA', 'ORG'),
#  ("Emkay Global's Lead Economist", 'WORK_OF_ART'),
#  ('Madhavi Arora', 'PERSON'),
#  ('Indian', 'NORP'),
#  ('the last 7-8 months', 'DATE'),
#  ('Acuite Ratings & Research', 'ORG'),
#  ('the next 1-2 quarters', 'DATE'),
#  ('Chowdhury', 'ORG'),
#  ('Centre', 'PERSON'),
#  ("Brickwork Ratings'", 'ORG'),
#  ('M. Govinda', 'PERSON'),
#  ("India Inc's", 'ORG'),
#  ('Modi', 'PRODUCT')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [( , 'O', ''),
#  ((, 'O', ''),
#  (Representational, 'O', ''),
#  (image, 'O', ''),
#  (), 'O', ''),
#  (The, 'O', ''),
#  (covid-19, 'O', ''),
#  (induced, 'O', ''),
#  (turmoil, 'O', ''),
#  (showed, 'O', ''),
#  (weakness, 'O', ''),
#  (as, 'O', ''),
#  (well, 'O', ''),
#  (as, 'O', ''),
#  (resilience, 'O', ''),
#  (of, 'O', ''),
#  (India, 'B', 'GPE'),
#  ('s, 'O', ''),
#  (economy, 'O', ''),
#  (in, 'O', ''),
#  (2020, 'B', 'DATE'),
#  (,, 'O', ''),
#  (as, 'O', ''),
#  (the, 'O', ''),
#  (country, 'O', ''),
#  ('s, 'O', ''),
#  (GDP, 'O', ''),
#  (recorded, 'O', ''),
#  (abysmal, 'O', ''),
#  (fall, 'O', ''),
#  (and, 'O', ''),
#  (breathtaking, 'O', ''),
#  (recovery, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (economy, 'O', ''),
#  (,, 'O', ''),
#  (which, 'O', ''),
#  (faced, 'O', ''),
#  (a, 'O', ''),
#  (severe, 'O', ''),
#  (slowdown, 'O', ''),
#  (prior, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (pandemic, 'O', ''),
#  (,, 'O', ''),
#  (was, 'O', ''),
#  (decimated, 'O', ''),
#  (due, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (lockdown, 'O', ''),
#  (imposed, 'O', ''),
#  (to, 'O', ''),
#  (curb, 'O', ''),
#  (the, 'O', ''),
#  (pandemic, 'O', ''),
#  ('s, 'O', ''),
#  (spread, 'O', ''),
#  (., 'O', ''),
#  (Accordingly, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (country, 'O', ''),
#  ('s, 'O', ''),
#  (GDP, 'O', ''),
#  (contracted, 'O', ''),
#  (by, 'O', ''),
#  (more, 'B', 'CARDINAL'),
#  (than, 'I', 'CARDINAL'),
#  (23, 'I', 'CARDINAL'),
#  (per, 'O', ''),
#  (cent, 'O', ''),
#  (in, 'O', ''),
#  (Q1FY21, 'B', 'GPE'),
#  (., 'O', ''),
#  (Nonetheless, 'O', ''),
#  (,, 'O', ''),
#  (slow, 'O', ''),
#  (tapering, 'O', ''),
#  (of, 'O', ''),
#  (mobility, 'O', ''),
#  (and, 'O', ''),
#  (lockdown, 'O', ''),
#  (restrictions, 'O', ''),
#  (along, 'O', ''),
#  (with, 'O', ''),
#  (pent, 'O', ''),
#  (up, 'O', ''),
#  (demand, 'O', ''),
#  (narrowed, 'O', ''),
#  (this, 'O', ''),
#  (contraction, 'O', ''),
#  (to, 'O', ''),
#  (under, 'B', 'MONEY'),
#  (10, 'I', 'MONEY'),
#  (per, 'I', 'MONEY'),
#  (cent, 'I', 'MONEY'),
#  (in, 'O', ''),
#  (Q2FY21, 'B', 'GPE'),
#  (., 'O', ''),
#  (Consequently, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (country, 'O', ''),
#  (entered, 'O', ''),
#  (into, 'O', ''),
#  (a, 'O', ''),
#  (technical, 'O', ''),
#  (recession, 'O', ''),
#  (., 'O', ''),
#  (Nevertheless, 'O', ''),
#  (,, 'O', ''),
#  (festive, 'O', ''),
#  (season, 'O', ''),
#  (,, 'O', ''),
#  (pent, 'O', ''),
#  (up, 'O', ''),
#  (demand, 'O', ''),
#  (and, 'O', ''),
#  (rise, 'O', ''),
#  (in, 'O', ''),
#  (discretionary, 'O', ''),
#  (spending, 'O', ''),
#  (coupled, 'O', ''),
#  (with, 'O', ''),
#  (massive, 'O', ''),
#  (liquidity, 'O', ''),
#  (and, 'O', ''),
#  (government, 'O', ''),
#  (stimulus, 'O', ''),
#  (triggered, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (the, 'O', ''),
#  (fastest, 'O', ''),
#  (recovery, 'O', ''),
#  (pattern, 'O', ''),
#  (seen, 'O', ''),
#  (anywhere, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (world, 'O', ''),
#  (., 'O', ''),
#  (ALSO, 'O', ''),
#  (READ, 'O', ''),
#  (|, 'O', ''),
#  ( , 'O', ''),
#  (', 'O', ''),
#  (People, 'O', ''),
#  (wo, 'O', ''),
#  (n't, 'O', ''),
#  (be, 'O', ''),
#  (misled, 'O', ''),
#  (', 'O', ''),
#  (:, 'O', ''),
#  (PM, 'B', 'ORG'),
#  (Modi, 'I', 'ORG'),
#  (rips, 'O', ''),
#  (into, 'O', ''),
#  (opposition, 'O', ''),
#  (for, 'O', ''),
#  (spreading, 'O', ''),
#  (lies, 'O', ''),
#  (on, 'O', ''),
#  (new, 'O', ''),
#  (farm, 'O', ''),
#  (laws, 'O', ''),
#  (Some, 'O', ''),
#  (economy, 'O', ''),
#  (watchers, 'O', ''),
#  (described, 'O', ''),
#  (the, 'O', ''),
#  (phenomenon, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (', 'O', ''),
#  (V, 'O', ''),
#  (', 'O', ''),
#  (shaped, 'O', ''),
#  (recovery, 'O', ''),
#  (,, 'O', ''),
#  (whereas, 'O', ''),
#  (,, 'O', ''),
#  (others, 'O', ''),
#  (pointed, 'O', ''),
#  (it, 'O', ''),
#  (out, 'O', ''),
#  (as, 'O', ''),
#  (', 'O', ''),
#  (U, 'O', ''),
#  (', 'O', ''),
#  (formation, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (restoration, 'O', ''),
#  (of, 'O', ''),
#  (economic, 'O', ''),
#  (normalcy, 'O', ''),
#  (., 'O', ''),
#  (All, 'O', ''),
#  (in, 'O', ''),
#  (all, 'O', ''),
#  (,, 'O', ''),
#  (sector, 'O', ''),
#  (after, 'O', ''),
#  (sector, 'O', ''),
#  (reported, 'O', ''),
#  (sequential, 'O', ''),
#  (growth, 'O', ''),
#  (with, 'O', ''),
#  (many, 'O', ''),
#  (crossing, 'O', ''),
#  (the, 'O', ''),
#  (year, 'O', ''),
#  (on, 'O', ''),
#  (year, 'B', 'DATE'),
#  (sales, 'O', ''),
#  (and, 'O', ''),
#  (production, 'O', ''),
#  (levels, 'O', ''),
#  (., 'O', ''),
#  (Besides, 'O', ''),
#  (,, 'O', ''),
#  (various, 'O', ''),
#  (factors, 'O', ''),
#  (such, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (low, 'O', ''),
#  (base, 'O', ''),
#  (,, 'O', ''),
#  (restocking, 'O', ''),
#  (and, 'O', ''),
#  (higher, 'O', ''),
#  (discretionary, 'O', ''),
#  (spends, 'O', ''),
#  (were, 'O', ''),
#  (cited, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (heightened, 'O', ''),
#  (economic, 'O', ''),
#  (activity, 'O', ''),
#  (which, 'O', ''),
#  (was, 'O', ''),
#  (led, 'O', ''),
#  (by, 'O', ''),
#  (agriculture, 'O', ''),
#  (,, 'O', ''),
#  (electricity, 'O', ''),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (manufacturing, 'O', ''),
#  (sectors, 'O', ''),
#  (., 'O', ''),
#  (Even, 'O', ''),
#  (though, 'O', ''),
#  (cheaper, 'O', ''),
#  (interest, 'O', ''),
#  (rates, 'O', ''),
#  (helped, 'O', ''),
#  (in, 'O', ''),
#  (spurring, 'O', ''),
#  (consumption, 'O', ''),
#  (,, 'O', ''),
#  (other, 'O', ''),
#  (vitals, 'O', ''),
#  (such, 'O', ''),
#  (as, 'O', ''),
#  (lower, 'O', ''),
#  (oil, 'O', ''),
#  (prices, 'O', ''),
#  (,, 'O', ''),
#  (lesser, 'O', ''),
#  (imports, 'O', ''),
#  (and, 'O', ''),
#  (an, 'O', ''),
#  (accelerated, 'O', ''),
#  (pick, 'O', ''),
#  (up, 'O', ''),
#  (of, 'O', ''),
#  (agricultural, 'O', ''),
#  (and, 'O', ''),
#  (pharma, 'O', ''),
#  (exports, 'O', ''),
#  (added, 'O', ''),
#  (positivity, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (economic, 'O', ''),
#  (scene, 'O', ''),
#  (., 'O', ''),
#  (After, 'O', ''),
#  (a, 'O', ''),
#  (healthy, 'O', ''),
#  (monsoon, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (country, 'O', ''),
#  ('s, 'O', ''),
#  (festive, 'O', ''),
#  (season, 'O', ''),
#  (coupled, 'O', ''),
#  (with, 'O', ''),
#  (', 'O', ''),
#  (unlock, 'O', ''),
#  (', 'O', ''),
#  (measures, 'O', ''),
#  (opened, 'O', ''),
#  (the, 'O', ''),
#  (floodgates, 'O', ''),
#  (for, 'O', ''),
#  (retail, 'O', ''),
#  (,, 'O', ''),
#  (wholesale, 'O', ''),
#  (and, 'O', ''),
#  (restocking, 'O', ''),
#  (,, 'O', ''),
#  (thereby, 'O', ''),
#  (,, 'O', ''),
#  (moving, 'O', ''),
#  (the, 'O', ''),
#  (wheels, 'O', ''),
#  (of, 'O', ''),
#  (economic, 'O', ''),
#  (revival, 'O', ''),
#  (., 'O', ''),
#  (Furthermore, 'O', ''),
#  (,, 'O', ''),
#  (stock, 'O', ''),
#  (markets, 'O', ''),
#  (boomed, 'O', ''),
#  (,, 'O', ''),
#  (as, 'O', ''),
#  (macro, 'O', ''),
#  (-, 'O', ''),
#  (economic, 'O', ''),
#  (data, 'O', ''),
#  (and, 'O', ''),
#  (better, 'O', ''),
#  (-, 'O', ''),
#  (than, 'O', ''),
#  (-, 'O', ''),
#  (expected, 'O', ''),
#  (quarterly, 'B', 'DATE'),
#  (results, 'O', ''),
#  (attracted, 'O', ''),
#  (FIIs, 'O', ''),
#  (with, 'O', ''),
#  (prospects, 'O', ''),
#  (of, 'O', ''),
#  (a, 'O', ''),
#  (return, 'O', ''),
#  (,, 'O', ''),
#  (something, 'O', ''),
#  (that, 'O', ''),
#  (has, 'O', ''),
#  (been, 'O', ''),
#  (missing, 'O', ''),
#  (in, 'O', ''),
#  (other, 'O', ''),
#  (asset, 'O', ''),
#  (classes, 'O', ''),
#  (throughout, 'O', ''),
#  (the, 'B', 'DATE'),
#  (year, 'I', 'DATE'),
#  (., 'O', ''),
#  (", 'O', ''),
#  (A, 'O', ''),
#  (tentative, 'O', ''),
#  (recovery, 'O', ''),
#  (in, 'O', ''),
#  (volumes, 'O', ''),
#  (is, 'O', ''),
#  (underway, 'O', ''),
#  (,, 'O', ''),
#  (which, 'O', ''),
#  (is, 'O', ''),
#  (being, 'O', ''),
#  (counteracted, 'O', ''),
#  (by, 'O', ''),
#  (rising, 'O', ''),
#  (raw, 'O', ''),
#  (material, 'O', ''),
#  (prices, 'O', ''),
#  (and, 'O', ''),
#  (to, 'O', ''),
#  (a, 'O', ''),
#  (smaller, 'O', ''),
#  (extent, 'O', ''),
#  (employee, 'O', ''),
#  (costs, 'O', ''),
#  (., 'O', ''),
#  (We, 'O', ''),
#  (expect, 'O', ''),
#  (the, 'O', ''),
#  (recovery, 'O', ''),
#  (to, 'O', ''),
#  (continue, 'O', ''),
#  (,, 'O', ''),
#  (albeit, 'O', ''),
#  (with, 'O', ''),
#  (a, 'O', ''),
#  (mild, 'O', ''),
#  (contraction, 'O', ''),
#  (in, 'O', ''),
#  (Q3, 'B', 'PERSON'),
#  (followed, 'O', ''),
#  (by, 'O', ''),
#  (a, 'O', ''),
#  (muted, 'O', ''),
#  (growth, 'O', ''),
#  (in, 'O', ''),
#  (Q4, 'B', 'PRODUCT'),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (said, 'O', ''),
#  (Aditi, 'B', 'PERSON'),
#  (Nayar, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (Principal, 'O', ''),
#  (Economist, 'O', ''),
#  (,, 'O', ''),
#  (ICRA, 'B', 'ORG'),
#  (., 'O', ''),
#  (   , 'O', ''),
#  (googletag.cmd.push(function, 'O', ''),
#  ((, 'O', ''),
#  (), 'O', ''),
#  ({, 'O', ''),
#  (googletag.display('div, 'O', ''),
#  (-, 'O', ''),
#  (gpt, 'O', ''),
#  (-, 'O', ''),
#  (ad-1516086534511, 'O', ''),
#  (-, 'O', ''),
#  (1, 'O', ''),
#  (', 'O', ''),
#  (), 'O', ''),
#  (;, 'O', ''),
#  (}, 'O', ''),
#  (), 'O', ''),
#  (;, 'O', ''),
#  (  , 'O', ''),
#  (On, 'O', ''),
#  (a, 'O', ''),
#  (sector, 'O', ''),
#  (specific, 'O', ''),
#  (basis, 'O', ''),
#  (,, 'O', ''),
#  (while, 'O', ''),
#  (agriculture, 'O', ''),
#  (and, 'O', ''),
#  (allied, 'O', ''),
#  (industries, 'O', ''),
#  (pushed, 'O', ''),
#  (the, 'O', ''),
#  (economy, 'O', ''),
#  (forward, 'O', ''),
#  (,, 'O', ''),
#  (manufacturing, 'O', ''),
#  (too, 'O', ''),
#  (came, 'O', ''),
#  (out, 'O', ''),
#  (of, 'O', ''),
#  (its, 'O', ''),
#  (doldrums, 'O', ''),
#  (even, 'O', ''),
#  (though, 'O', ''),
#  (it, 'O', ''),
#  (has, 'O', ''),
#  (dipped, 'O', ''),
#  (slightly, 'O', ''),
#  (ever, 'O', ''),
#  (since, 'O', ''),
#  (., 'O', ''),
#  (However, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (service, 'O', ''),
#  (sector, 'O', ''),
#  ('s, 'O', ''),
#  (contribution, 'O', ''),
#  (was, 'O', ''),
#  (lacking, 'O', ''),
#  (in, 'O', ''),
#  (giving, 'O', ''),
#  (a, 'O', ''),
#  (real, 'O', ''),
#  (push, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (GDP, 'O', ''),
#  (., 'O', ''),
#  (Now, 'O', ''),
#  (with, 'O', ''),
#  (hopes, 'O', ''),
#  (of, 'O', ''),
#  (a, 'O', ''),
#  (mass, 'O', ''),
#  (immunisation, 'O', ''),
#  (programme, 'O', ''),
#  (armed, 'O', ''),
#  (with, 'O', ''),
#  (a, 'O', ''),
#  (high, 'O', ''),
#  (efficacy, 'O', ''),
#  (backed, 'O', ''),
#  (vaccine, 'O', ''),
#  (,, 'O', ''),
#  (front, 'O', ''),
#  (and, 'O', ''),
#  (back, 'O', ''),
#  (end, 'O', ''),
#  (services, 'O', ''),
#  (are, 'O', ''),
#  (expected, 'O', ''),
#  (to, 'O', ''),
#  (bounce, 'O', ''),
#  (back, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (The, 'O', ''),
#  (next, 'O', ''),
#  (leg, 'O', ''),
#  (of, 'O', ''),
#  (sequential, 'O', ''),
#  (recovery, 'O', ''),
#  (may, 'O', ''),
#  (emerge, 'O', ''),
#  (from, 'O', ''),
#  (services, 'O', ''),
#  (which, 'O', ''),
#  (has, 'O', ''),
#  (been, 'O', ''),
#  (a, 'O', ''),
#  (laggard, 'O', ''),
#  (so, 'O', ''),
#  (far, 'O', ''),
#  (,, 'O', ''),
#  (while, 'O', ''),
#  (government, 'O', ''),
#  (spending, 'O', ''),
#  (may, 'O', ''),
#  (also, 'O', ''),
#  (improve, 'O', ''),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (margin, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (Emkay, 'B', 'WORK_OF_ART'),
#  (Global, 'I', 'WORK_OF_ART'),
#  ('s, 'I', 'WORK_OF_ART'),
#  (Lead, 'I', 'WORK_OF_ART'),
#  (Economist, 'I', 'WORK_OF_ART'),
#  (Madhavi, 'B', 'PERSON'),
#  (Arora, 'I', 'PERSON'),
#  (said, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (We, 'O', ''),
#  (see, 'O', ''),
#  (FY21, 'O', ''),
#  (growth, 'O', ''),
#  (at, 'O', ''),
#  ((, 'O', ''),
#  (-)7.1, 'O', ''),
#  (per, 'O', ''),
#  (cent, 'O', ''),
#  (with, 'O', ''),
#  (a, 'O', ''),
#  (mild, 'O', ''),
#  (downward, 'O', ''),
#  (bias, 'O', ''),
#  (., 'O', ''),
#  (We, 'O', ''),
#  (reckon, 'O', ''),
#  (while, 'O', ''),
#  (2HFY21, 'O', ''),
#  (will, 'O', ''),
#  (see, 'O', ''),
#  (further, 'O', ''),
#  (pick, 'O', ''),
#  (up, 'O', ''),
#  (,, 'O', ''),
#  (sustaining, 'O', ''),
#  (sequential, 'O', ''),
#  (growth, 'O', ''),
#  (momentum, 'O', ''),
#  (beyond, 'O', ''),
#  (that, 'O', ''),
#  (will, 'O', ''),
#  (require, 'O', ''),
#  (easing, 'O', ''),
#  (domestic, 'O', ''),
#  (structural, 'O', ''),
#  (overhang, 'O', ''),
#  (,, 'O', ''),
#  (continued, 'O', ''),
#  (innovative, 'O', ''),
#  (policy, 'O', ''),
#  (support, 'O', ''),
#  (and, 'O', ''),
#  (better, 'O', ''),
#  (global, 'O', ''),
#  (backdrop, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (she, 'O', ''),
#  (added, 'O', ''),
#  (., 'O', ''),
#  (Apart, 'O', ''),
#  (from, 'O', ''),
#  (the, 'O', ''),
#  (government, 'O', ''),
#  (spending, 'O', ''),
#  (or, 'O', ''),
#  (the, 'O', ''),
#  (private, 'O', ''),
#  (final, 'O', ''),
#  (consumption, 'O', ''),
#  (,, 'O', ''),
#  (it, 'O', ''),
#  (was, 'O', ''),
#  (savings, 'O', ''),
#  (backed, 'O', ''),
#  (discretionary, 'O', ''),
#  (spends, 'O', ''),
#  (of, 'O', ''),
#  (common, 'O', ''),
#  (households, 'O', ''),
#  (that, 'O', ''),
#  (came, 'O', ''),
#  (in, 'O', ''),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (saviour, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (economy, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (We, 'O', ''),
#  (believe, 'O', ''),
#  (that, 'O', ''),
#  (the, 'O', ''),
#  (accumulated, 'O', ''),
#  (savings, 'O', ''),
#  (of, 'O', ''),
#  (particularly, 'O', ''),
#  (the, 'O', ''),
#  (Indian, 'B', 'NORP'),
#  (salaried, 'O', ''),
#  (class, 'O', ''),
#  (over, 'O', ''),
#  (the, 'B', 'DATE'),
#  (last, 'I', 'DATE'),
#  (7, 'I', 'DATE'),
#  (-, 'I', 'DATE'),
#  (8, 'I', 'DATE'),
#  (months, 'I', 'DATE'),
#  (due, 'O', ''),
#  (to, 'O', ''),
#  (limited, 'O', ''),
#  (expenses, 'O', ''),
#  (on, 'O', ''),
#  (travel, 'O', ''),
#  (and, 'O', ''),
#  (entertainment, 'O', ''),
#  (will, 'O', ''),
#  (get, 'O', ''),
#  (partly, 'O', ''),
#  (diverted, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (purchase, 'O', ''),
#  (of, 'O', ''),
#  (vehicles, 'O', ''),
#  (and, 'O', ''),
#  (consumer, 'O', ''),
#  (durables, 'O', ''),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (Acuite, 'B', 'ORG'),
#  (Ratings, 'I', 'ORG'),
#  (&, 'I', 'ORG'),
#  (Research, 'I', 'ORG'),
#  (Chief, 'O', ''),
#  (Analytical, 'O', ''),
#  (Officer, 'O', ''),
#  (Suman, 'O', ''),
#  (Chowdhury, 'O', ''),
#  (said, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (This, 'O', ''),
#  (is, 'O', ''),
#  (already, 'O', ''),
#  (reflected, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (uptick, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (demand, 'O', ''),
#  (of, 'O', ''),
#  (these, 'O', ''),
#  (products, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (pent, 'O', ''),
#  (up, 'O', ''),
#  (demand, 'O', ''),
#  (and, 'O', ''),
#  (the, 'O', ''),
#  (availability, 'O', ''),
#  (of, 'O', ''),
#  (higher, 'O', ''),
#  (savings, 'O', ''),
#  (,, 'O', ''),
#  (therefore, 'O', ''),
#  (is, 'O', ''),
#  (expected, 'O', ''),
#  (to, 'O', ''),
#  (drive, 'O', ''),
#  (consumption, 'O', ''),
#  (demand, 'O', ''),
#  (over, 'O', ''),
#  (the, 'B', 'DATE'),
#  (next, 'I', 'DATE'),
#  (1, 'I', 'DATE'),
#  (-, 'I', 'DATE'),
#  (2, 'I', 'DATE'),
#  (quarters, 'I', 'DATE'),
#  (,, 'O', ''),
#  (", 'O', ''),
#  (Chowdhury, 'B', 'ORG'),
#  (added, 'O', ''),
#  (., 'O', ''),
#  (Other, 'O', ''),
#  (than, 'O', ''),
#  (stimulus, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (Centre, 'B', 'PERSON'),
#  ('s, 'O', ''),
#  (structural, 'O', ''),
#  (reforms, 'O', ''),
#  (,, 'O', ''),
#  (focus, 'O', ''),
#  (on, 'O', ''),
#  (the, 'O', ''),
#  (manufacturing, 'O', ''),
#  (sector, 'O', ''),
#  (and, 'O', ''),
#  (inflow, 'O', ''),
#  (of, 'O', ''),
#  (FDI, 'O', ''),
#  (into, 'O', ''),
#  (the, 'O', ''),
#  (country, 'O', ''),
#  (are, 'O', ''),
#  (likely, 'O', ''),
#  (to, 'O', ''),
#  (hasten, 'O', ''),
#  (the, 'O', ''),
#  (pace, 'O', ''),
#  (of, 'O', ''),
#  (economic, 'O', ''),
#  (recovery, 'O', ''),
#  (., 'O', ''),
#  (According, 'O', ''),
#  (to, 'O', ''),
#  (Brickwork, 'B', 'ORG'),
#  (Ratings, 'I', 'ORG'),
#  (', 'I', 'ORG'),
#  (Chief, 'O', ''),
#  (Economic, 'O', ''),
#  (Adviser, 'O', ''),
#  (M., 'B', 'PERSON'),
#  (Govinda, 'I', 'PERSON'),
#  (Rao, 'O', ''),
#  (:, 'O', ''),
#  (", 'O', ''),
#  (The, 'O', ''),
#  (economy, 'O', ''),
#  (will, 'O', ''),
#  (continue, 'O', ''),
#  (to, 'O', ''),
#  (recover, 'O', ''),
#  (as, 'O', ''),
#  (restrictions, 'O', ''),
#  (are, 'O', ''),
#  (relaxed, 'O', ''),
#  (and, 'O', ''),
#  (capacity, 'O', ''),
#  (utilisation, 'O', ''),
#  (improves, 'O', ''),
#  (., 'O', ''),
#  (It, 'O', ''),
#  (is, 'O', ''),
#  (important, 'O', ''),
#  (to, 'O', ''),
#  (undertake, 'O', ''),
#  (structural, 'O', ''),
#  (reforms, 'O', ''),
#  (to, 'O', ''),
#  (accelerate, 'O', ''),
#  (the, 'O', ''),
#  (pace, 'O', ''),
#  (of, 'O', ''),
#  (investment, 'O', ''),
#  (in, 'O', ''),
#  (order, 'O', ''),
#  (to, 'O', ''),
#  (reclaim, 'O', ''),
#  (a, 'O', ''),
#  (high, 'O', ''),
#  (growth, 'O', ''),
#  (trajectory, 'O', ''),
#  (., 'O', ''),
#  (", 'O', ''),
#  (In, 'O', ''),
#  (addition, 'O', ''),
#  (,, 'O', ''),
#  (experts, 'O', ''),
#  (cited, 'O', ''),
#  (India, 'B', 'ORG'),
#  (Inc, 'I', 'ORG'),
#  ('s, 'I', 'ORG'),
#  (massive, 'O', ''),
#  (shift, 'O', ''),
#  (to, 'O', ''),
#  (e, 'O', ''),
#  (-, 'O', ''),
#  (com, 'O', ''),
#  (,, 'O', ''),
#  (acceptance, 'O', ''),
#  (of, 'O', ''),
#  (higher, 'O', ''),
#  (safety, 'O', ''),
#  (standards, 'O', ''),
#  (and, 'O', ''),
#  (inculcation, 'O', ''),
#  (of, 'O', ''),
#  (efficiency, 'O', ''),
#  (boosting, 'O', ''),
#  (measures, 'O', ''),
#  (as, 'O', ''),
#  (other, 'O', ''),
#  (notable, 'O', ''),
#  (trends, 'O', ''),
#  (during, 'O', ''),
#  (this, 'O', ''),
#  (historic, 'O', ''),
#  (period, 'O', ''),
#  (., 'O', ''),
#  (ALSO, 'O', ''),
#  (READ, 'O', ''),
#  (|, 'O', ''),
#  ( , 'O', ''),
#  (No, 'O', ''),
#  (corporate, 'O', ''),
#  (can, 'O', ''),
#  (snatch, 'O', ''),
#  (away, 'O', ''),
#  (farmer, 'O', ''),
#  ('s, 'O', ''),
#  (land, 'O', ''),
#  (till, 'O', ''),
#  (Modi, 'B', 'PRODUCT'),
#  (is, 'O', ''),
#  (PM, 'O', ''),
#  (:, 'O', ''),
#  (Amit, 'O', ''),
#  (Shah, 'O', ''),
#  (Latest, 'O', ''),
#  (Business, 'O', ''),
#  (News, 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re
import en_core_web_sm
nlp = en_core_web_sm.load()
import spacy
from spacy import displacy
from collections import Counter

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://www.indiatvnews.com/business/news-india-gdp-quickest-to-fall-fastest-to-recover-673985')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 207

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'GPE': 31,
#          'ORG': 48,
#          'DATE': 22,
#          'LANGUAGE': 1,
#          'PERSON': 56,
#          'CARDINAL': 17,
#          'MONEY': 2,
#          'PRODUCT': 5,
#          'WORK_OF_ART': 9,
#          'NORP': 4,
#          'ORDINAL': 6,
#          'PERCENT': 2,
#          'LOC': 2,
#          'QUANTITY': 1,
#          'EVENT': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('India', 11), ('Kohli', 4), ('14', 3)]

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# The economy, which faced a severe slowdown prior to the pandemic, was decimated due to the lockdown imposed to curb the pandemic's spread.

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# C:\Users\ShubhamShukla\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The economy, which faced a severe slowdown prior to the pandemic, was decimated due to the lockdown imposed to curb the pandemic's spread.</div></span>

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="82ca887711224004aad347d36e18ff16-0" class="displacy" width="2930" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">economy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">faced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">severe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">slowdown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">prior</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">pandemic,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">decimated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">due</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">lockdown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">imposed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">curb</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">pandemic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">spread.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82ca887711224004aad347d36e18ff16-0-0" stroke-width="2px" d="M70,302.0 C70,242.0 150.0,242.0 150.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82ca887711224004aad347d36e18ff16-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82ca887711224004aad347d36e18ff16-0-1" stroke-width="2px" d="M190,302.0 C190,2.0 1490.0,2.0 1490.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82ca887711224004aad347d36e18ff16-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,304.0 L182,292.0 198,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82ca887711224004aad347d36e18ff16-0-2" stroke-width="2px" d="M310,302.0 C310,242.0 390.0,242.0 390.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82ca887711224004aad347d36e18ff16-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,304.0 L302,292.0 318,292.0" fill="curren

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('economy', 'NOUN', 'economy'),
#  ('faced', 'VERB', 'face'),
#  ('severe', 'ADJ', 'severe'),
#  ('slowdown', 'NOUN', 'slowdown'),
#  ('prior', 'ADV', 'prior'),
#  ('pandemic', 'NOUN', 'pandemic'),
#  ('decimated', 'VERB', 'decimate'),
#  ('lockdown', 'NOUN', 'lockdown'),
#  ('imposed', 'VERB', 'impose'),
#  ('curb', 'VERB', 'curb'),
#  ('pandemic', 'NOUN', 'pandemic'),
#  ('spread', 'NOUN', 'spread')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences)).ents])
# Out:
# {'India': 'GPE',
#  '| Business News': 'ORG',
#  'Monday, December 28,': 'DATE',
#  'English': 'LANGUAGE',
#  'Android   ': 'PERSON',
#  'Facebook Twitter': 'PERSON',
#  'Videos': 'PERSON',
#  'Tech': 'ORG',
#  'Education': 'ORG',
#  'Photos        Health        Trending        Lifestyle        Bigg Boss 14': 'WORK_OF_ART',
#  'Jobs Results': 'PERSON',
#  'Quickest': 'NORP',
#  '2020': 'DATE',
#  'IANS': 'ORG',
#  'New Delhi': 'GPE',
#  'December 25, 2020 23:17': 'DATE',
#  'IST': 'ORG',
#  'more than 23': 'CARDINAL',
#  'Q1FY21.': 'GPE',
#  'under 10 per cent': 'MONEY',
#  'Q2FY21.': 'GPE',
#  'one': 'CARDINAL',
#  'PM Modi': 'ORG',
#  'year': 'DATE',
#  'quarterly': 'DATE',
#  'the year': 'DATE',
#  'Q3': 'PERSON',
#  'Q4': 'PRODUCT',
#  'Aditi Nayar': 'PERSON',
#  'ICRA': 'ORG',
#  "Emkay Global's Lead Economist": 'WORK_OF_ART',
#  'Madhavi Arora': 'PERSON',
#  'Indian': 'NORP',
#  'the last 7-8 months': 'DATE',
#  'Acuite Ratings & Research': 'ORG',
#  'the next 1-2 quarters': 'DATE',
#  'Chowdhury': 'ORG',
#  'Centre': 'PERSON',
#  "Brickwork Ratings'": 'ORG',
#  'M. Govinda': 'PERSON',
#  "India Inc's": 'ORG',
#  'Modi': 'PRODUCT',
#  'Watch Live News :                  ': 'WORK_OF_ART',
#  'Ramdas Athawale': 'ORG',
#  'UK': 'GPE',
#  'COVID': 'ORG',
#  'Nirmala Mishra': 'PERSON',
#  'Kohli': 'PERSON',
#  'Rahane': 'PERSON',
#  'Merry Christmas 2020': 'DATE',
#  'Facebook Greetings': 'PERSON',
#  'WhatsApp': 'ORG',
#  'Salman Khan': 'PERSON',
#  'Bhaijaan': 'GPE',
#  'celebs &': 'ORG',
#  'Finance': 'ORG',
#  'GST council': 'ORG',
#  'GST': 'ORG',
#  'PUBG Mobile': 'PERSON',
#  'MeitY': 'CARDINAL',
#  'Latest News': 'ORG',
#  'AUS vs IND 2nd Test | Rahane': 'PRODUCT',
#  'Jadeja': 'ORG',
#  'Australia': 'GPE',
#  'Tendulkar': 'ORG',
#  '55th': 'ORDINAL',
#  'Radhe': 'PERSON',
#  'the Press Salaam India Awards Investors Column': 'FAC',
#  '21 Years': 'DATE',
#  'Aap ki': 'ORG',
#  'Other Services': 'ORG',
#  'Hindi News': 'ORG',
#  'India Sports News Business News India Business News Stock Market': 'ORG',
#  'Independent News Service': 'ORG',
#  'Aap Ki Adalat': 'PERSON',
#  'Aaj Ki': 'PERSON',
#  'Baat': 'PERSON',
#  'Entertainment': 'ORG',
#  'Rahul Gandhi': 'PERSON',
#  'Congress': 'ORG',
#  'Randeep Surjewala': 'PERSON',
#  'Haqikat Kya Hai': 'PERSON',
#  '6th': 'ORDINAL',
#  'govt': 'ORG',
#  'Farmers Union': 'ORG',
#  'Dec 29': 'LAW',
#  'Ujjain': 'GPE',
#  'Pragaraj': 'GPE',
#  'House': 'ORG',
#  'Ramnidhi Sangrahan': 'ORG',
#  'RCP Singh': 'PRODUCT',
#  'Goa': 'PERSON',
#  'Narasimha Rao': 'PERSON',
#  'Venkaiah Naidu': 'PERSON',
#  'World          Entertainment     Entertainment': 'ORG',
#  'Gallery': 'PERSON',
#  'Reviews': 'PERSON',
#  'Bhojpuri': 'PERSON',
#  'Gossip': 'PERSON',
#  'Hollywood': 'GPE',
#  'SBAS': 'PERSON',
#  'Bengali': 'NORP',
#  'Kangana Ranaut': 'PERSON',
#  'Rakh': 'WORK_OF_ART',
#  "Varun Dhawan's": 'PERSON',
#  'Rashmi Rocket': 'PERSON',
#  'Taapsee': 'GPE',
#  'Rajinikanth': 'ORG',
#  'Sunday': 'DATE',
#  'Over 4.15': 'CARDINAL',
#  'fiscal 2019-20': 'DATE',
#  'Dec 26       LED TV': 'ORG',
#  '10%': 'PERCENT',
#  'January': 'DATE',
#  'Govt': 'ORG',
#  'March 31': 'DATE',
#  '1%': 'PERCENT',
#  'January 1': 'DATE',
#  'Live Scores': 'FAC',
#  'Tennis': 'ORG',
#  'SA': 'ORG',
#  '1st': 'ORDINAL',
#  'Dean Elgar': 'PERSON',
#  'Aiden Markram': 'ORG',
#  'South Africa': 'GPE',
#  'Dhoni': 'PERSON',
#  "ICC Men's": 'ORG',
#  'ODI Team': 'ORG',
#  'the Decade': 'DATE',
#  'Sports Ministry': 'ORG',
#  '50 per cent': 'MONEY',
#  'IND vs AUS': 'PRODUCT',
#  'Jinks': 'PERSON',
#  'Virat Kohli': 'PERSON',
#  "Ajinkya Rahane's": 'PERSON',
#  'MeitY        Apps': 'PERSON',
#  'TikTok': 'ORG',
#  'CamScanner': 'ORG',
#  'Christmas': 'DATE',
#  'Instagram': 'NORP',
#  'UGC': 'ORG',
#  'over 100': 'CARDINAL',
#  'UG': 'ORG',
#  '10': 'CARDINAL',
#  '12': 'CARDINAL',
#  'December 31': 'DATE',
#  'West Bengal': 'GPE',
#  'WBBSE': 'PERSON',
#  'WBCHSE board': 'ORG',
#  'Second': 'ORDINAL',
#  'Ex-SBI': 'ORG',
#  'Odisha': 'GPE',
#  'NEET': 'GPE',
#  'first-year': 'DATE',
#  'PhD': 'LOC',
#  'IIT Delhi': 'GPE',
#  'Photos': 'GPE',
#  "Salman Khan's": 'PERSON',
#  'Aamir Khan': 'PERSON',
#  'Kiran Rao': 'PERSON',
#  '15th': 'ORDINAL',
#  'Anupamaa': 'GPE',
#  "Madalsa Sharma's": 'PERSON',
#  'Karishma Tanna:': 'PERSON',
#  'Ali Khan': 'PERSON',
#  'Knee': 'PERSON',
#  'Six feet': 'QUANTITY',
#  "'King of Corona Times'": 'WORK_OF_ART',
#  'Trending          Lifestyle     Lifestyle  Health  Relationships  Fashion  Astrology  , Food  Beauty  , Culture  Travel        , Merry Christmas 2020: Wishes, Quotes': 'WORK_OF_ART',
#  'Messages       Decorate': 'PERSON',
#  'Christmas 2020': 'DATE',
#  '6': 'CARDINAL',
#  'Cancerians': 'NORP',
#  'Bigg Boss 14': 'WORK_OF_ART',
#  'Nikki Tamboli': 'PERSON',
#  'Aly Goni': 'PERSON',
#  'Vikas & Sonali': 'ORG',
#  '14': 'CARDINAL',
#  'Rakhi Sawant': 'PERSON',
#  'Bigg Boss 14:': 'WORK_OF_ART',
#  'Kashmera Shah': 'ORG',
#  'Krushna Abhishek       ': 'PERSON',
#  'Eijaz Khan': 'PERSON',
#  'Manu Punjabi': 'PERSON',
#  "Rahul Vaidya '": 'PERSON'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[40]])
# Out:
# [(", 'O', ''), (The, 'O', ''), (next, 'O', ''), (leg, 'O', ''), (of, 'O', ''), (sequential, 'O', ''), (recovery, 'O', ''), (may, 'O', ''), (emerge, 'O', ''), (from, 'O', ''), (services, 'O', ''), (which, 'O', ''), (has, 'O', ''), (been, 'O', ''), (a, 'O', ''), (laggard, 'O', ''), (so, 'O', ''), (far, 'O', ''), (,, 'O', ''), (while, 'O', ''), (government, 'O', ''), (spending, 'O', ''), (may, 'O', ''), (also, 'O', ''), (improve, 'O', ''), (at, 'O', ''), (the, 'O', ''), (margin, 'O', ''), (,, 'O', ''), (", 'O', ''), (Emkay, 'B', 'WORK_OF_ART'), (Global, 'I', 'WORK_OF_ART'), ('s, 'I', 'WORK_OF_ART'), (Lead, 'I', 'WORK_OF_ART'), (Economist, 'I', 'WORK_OF_ART'), (Madhavi, 'B', 'PERSON'), (Arora, 'I', 'PERSON'), (said, 'O', ''), (., 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  GDP Quickest to fall fastest to recover
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     | Business News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  –
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  TV
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday, December 28, 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#  हिन्दी     iOS
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# Facebook Twitter You tube                     Live tv                       Videos
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#         World        Entertainment        Business        Sports        Tech        Education        Photos        Health        Trending        Lifestyle        Bigg Boss
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                       Politics Auto Science Crime FYI Jobs Results Latest News Brand Content हिन्दी                               You Are At:  English News    Business
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's GDP: Quickest to fall, fastest to recover
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's GDP: Quickest to fall, fastest to recover  The covid-19 induced turmoil showed weakness as well as resilience of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's economy in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as the country's GDP recorded abysmal fall and breathtaking recovery.        IANS
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Published on:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 25, 2020 23:17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  IST                               Image Source : FILE PHOTO (Representational image)    The covid-19 induced turmoil showed weakness as well as resilience of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's economy in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as the country's GDP recorded abysmal fall and breathtaking recovery. The economy, which faced a severe slowdown prior to the pandemic, was decimated due to the lockdown imposed to curb the pandemic's spread. Accordingly, the country's GDP contracted by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  per cent in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q1FY21
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Nonetheless, slow tapering of mobility and lockdown restrictions along with pent up demand narrowed this contraction to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     under 10 per cent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2FY21
#     <span style="font-size
